# %% [markdown]
# # Disaster Risk Monitoring Using Satellite Imagery #

# %% [markdown]
# ## 02 - Efficient Model Training ##
# In this notebook, you will learn how to train a segmentation model with the TAO Toolkit using pre-trained ResNet-18 weights. In addition, you will learn how to export the model for deployment.
#
# **Table of Contents**
# <br>
# This notebook covers the below sections:
# 1. [Introduction to the TAO Toolkit](#s2-1)
#     * [Transfer Learning](#s2-1.1)
#     * [Vision AI Pre-Trained Models Supported](#s2-1.2)
#     * [TAO Toolkit Workflow](#s2-1.3)
#     * [TAO Launcher, CLI (Command Line Interface), and Spec Files](#s2-1.4)
#     * [Set Up Environment Variables](#s2-1.5)
#     * [Exercise #1 - Explore TAO Toolkit CLI](#s2-e1)
# 2. [U-Net Semantic Segmentation Model](#s2-2)
#     * [Preparation for Model Training](#s2-2.1)
#     * [Download Pre-Trained Model](#s2-2.2)
#     * [Prepare Dataset](#s2-2.3)
#     * [Model Training](#s2-2.4)
#     * [Exercise #2 - Modify Dataset Config](#s2-e2)
#     * [Exercise #3 - Modify Model Config](#s2-e3)
#     * [Exercise #4 - Modify Training Config](#s2-e4)
#     * [Combine Configuration Files](#s2-2.5)
#     * [Initiate Model Training](#s2-2.6)
#     * [Evaluating the Model](#s2-2.7)
#     * [Visualizing Model Inference](#s2-2.8)
# 3. [Model Export](#s2-3)
#     * [TensorRT - Programmable Inference Accelerator](#s2-3.1)
#     * [Export the Trained Model](#s2-3.2)
#     * [Generate TensorRT Engine](#s2-3.3)

# %% [markdown]
# ## Introduction to the TAO Toolkit ##
# The TAO Toolkit, Train Adapt Optimize, is a framework that simplifies the AI/ML model development workflow. It lets developers fine-tune pre-trained models with custom data to produce highly accurate computer vision models efficiently, eliminating the need for large training runs and deep AI expertise. In addition, it also enables model optimization for inference performance. You can learn more about the TAO Toolkit [here](https://developer.nvidia.com/tao-toolkit) or read the documentation [here](https://docs.nvidia.com/tao/tao-toolkit/index.html#).
#
# The TAO Toolkit uses pre-trained models to accelerate the AI development process and reduce costs associated with large scale data collection, labeling, and training models from scratch. Transfer learning with pre-trained models can be used for classification, object detection, and image segmentation tasks. The TAO Toolkit offers useful features such as:
# * Low-coding approach that requires no AI framework expertise, reducing the barrier of entry for anyone who wants to get started building AI-based applications
# * Flexible configurations that allow customization to help advance users prototype faster
# * Large catalogue of production-ready pre-trained models for common Computer Vision (CV) tasks that can also be customized with users' own data
# * Easy to use interface for model optimization such as pruning and quantization-aware training
# * Integration with the Triton Inference Server
#
# _Note: The TAO Toolkit comes with a set of reference scripts and configuration specifications with default parameter values that enable developers to kick-start training and fine-tuning. This lowers the bar and enables users without a deep understanding of models, expertise in deep learning, or beginning coding skills to be able to train new models and fine-tune the pre-trained ones._

# %% [markdown]
# ### Transfer Learning ###
# In practice, it is rare and inefficient to initiate the learning task on a network with randomly initialized weights due to factors like data scarcity (inadequate number of training samples) or prolonged training times. One of the most common techniques to overcome this is to use transfer learning. Transfer learning is the process of transferring learned features from one application to another. It is a commonly used training technique where developers use a model trained on one task and re-train to use it on a different task. This works surprisingly well as many of the early layers in a neural network are the same for similar tasks. For example, many of the early layers in a convolutional neural network used for a CV model are primarily used to identify outlines, curves, and other features in an image. The network formed by these layers are referred to as the **backbone** of a more complex model. Also known as feature extractors, they take as input the image and extracts the feature map upon which the rest of the network is based. The learned features from these layers can be applied to similar tasks carrying out the same identification in other domains. Transfer learning enables adaptation (fine-tuning) of an existing neural network to a new one, which requires significantly less domain-specific data. In most cases, fine-tuning takes significantly less time (a reduction by x10 factor is common), saving time and resources. As it relates to vision AI, transfer learning can be used for adding new classification by transferring weights from one application to another.
#
#
# More information about transfer learning can be found in this [blog](https://blogs.nvidia.com/blog/2019/02/07/what-is-transfer-learning/).

# %% [markdown]
# ### Vision AI Pre-Trained Models Supported ###
# Developers, system builders, and software partners building disaster risk monitoring systems can bring their own custom data to train with and fine-tune pre-trained models quickly instead of going through significant effort in large data collection and training from scratch. **General purpose vision models** provide pre-trained weights for popular network architectures to train an image classification model, an object detection model, or a segmentation model. This gives users the flexibility and control to build AI models for any number of applications, from smaller lightweight models for edge deployment to larger models for more complex tasks. They are trained on the [Open Images](https://opensource.google/projects/open-images-dataset) dataset and provide a much better starting point for training versus training from scratch or starting from random weights.
#
# The TAO Toolkit adapts popular network architectures and backbones to custom data, allowing developers to train, fine tune, prune, and export highly optimized and accurate AI models. When working with TAO, first choose the model architecture to be built, then choose one of the supported backbones.
#
# _Note: The pre-trained weights from each feature extraction network merely act as a starting point and may not be used without re-training. In addition, the pre-trained weights are network specific and shouldn't be shared across models that use different architectures._

# %% [markdown]
# ### TAO Toolkit Workflow ###
# Building disaster risk monitoring systems is hard, and tailoring even a single component to the needs of the enterprise for deployment is even harder. Deployment for a domain-specific application typically requires several cycles of re-training, fine-tuning, and deploying the model until it satisfies the requirements. As a starting point, training typically follows the below steps:
#
# 0. Configuration
# 1. Download a pre-trained model from NGC
# 2. Prepare the data for training
# 3. Train the model using transfer learning
# 4. Evaluate the model for target predictions
# 5. Export the model
# * Steps to optimize the model for improved inference performance

# %% [markdown]
# ### TAO Launcher, CLI (Command Line Interface), and Spec Files ###
# The TAO Toolkit is a low-coding framework that makes it easy to get started. It uses a **launcher** to pull from NGC registry and instantiate the appropriate TAO [container](https://www.docker.com/resources/what-container/) that performs the desired subtasks such as convert data, train, evaluate, or export. The TAO launcher is a python package distributed as a python wheel listed in the `nvidia-pyindex` python index, which has been prepared for you already.
#
# Users interact with the launcher with its **Command Line Interface** that is configured using simple [**Protocol Buffer**](https://developers.google.com/protocol-buffers) **specification files** to include parameters such as the dataset parameters, model parameters, and optimizer and training hyperparameters. More information about the TAO Toolkit Launcher can be found in the [TAO Docs](https://docs.nvidia.com/tao/tao-toolkit/text/tao_launcher.html#tao-launcher).
#
# The tasks can be invoked from the TAO Toolkit Launcher using the convention `tao <task_group> <task> <subtask> <args_per_subtask>`, where `<args_per_subtask>` are the arguments required for a given subtask. The tasks in the containers are grouped into different task_groups, which are divided into the following categories:
# * `model`
# * `dataset`
# * `deploy`
#
# The tasks under `model` contain routines to perform `train`, `evaluate`, and `inference` on one of any number of deep neural network models supported by TAO. The tasks under `dataset` contain routines to manipulate datasets, such as augment and auto_label, while the tasks under `deploy` optimize and deploy models to TensorRT.
#
# Once the container is launched, the subtasks are run by the TAO Toolkit containers using the appropriate hardware resources.

# %% [markdown]
# Since the TAO Toolkit uses the launcher to pull containers, the first time running a task may take extra time to load.

# %% [markdown]
# <a name='s2-1.5'></a>
# ### Set Up Environment Variables ###
# We set up a couple of environment variables to help us mount the local directories to the tao container. Specifically, we want to set paths for the `$LOCAL_TRAINING_DATA`, `$LOCAL_SPEC_DIR`, and `$LOCAL_PROJECT_DIR` for the output of the TAO experiment with their respective paths in the TAO container. In doing so, we can make sure that the TAO experiment generated collaterals such as checkpoints, model files (e.g. `.tlt` or `.etlt`), and logs are output to `$LOCAL_PROJECT_DIR/unet`.
#
# _Note that users will be able to define their own export encryption key when training from a general-purpose model. This is to protect proprietary IP and used to decrypt the `.etlt` model during deployment._

# %%
# DO NOT CHANGE THIS CELL
# set environment variables
import os
import json

# %set_env KEY=my_model_key

# %set_env LOCAL_PROJECT_DIR=/dli/task/tao_project
# %set_env LOCAL_DATA_DIR=/dli/task/flood_data
# %set_env LOCAL_SPECS_DIR=/dli/task/tao_project/spec_files
os.environ["LOCAL_EXPERIMENT_DIR"]=os.path.join(os.getenv("LOCAL_PROJECT_DIR"), "unet")

# %set_env TAO_PROJECT_DIR=/workspace/tao-experiments
# %set_env TAO_DATA_DIR=/workspace/tao-experiments/data
# %set_env TAO_SPECS_DIR=/workspace/tao-experiments/spec_files
# %set_env TAO_EXPERIMENT_DIR=/workspace/tao-experiments/unet

# !mkdir $LOCAL_EXPERIMENT_DIR
# Out:
# env: KEY=my_model_key
# env: LOCAL_PROJECT_DIR=/dli/task/tao_project
# env: LOCAL_DATA_DIR=/dli/task/flood_data
# env: LOCAL_SPECS_DIR=/dli/task/tao_project/spec_files
# env: TAO_PROJECT_DIR=/workspace/tao-experiments
# env: TAO_DATA_DIR=/workspace/tao-experiments/data
# env: TAO_SPECS_DIR=/workspace/tao-experiments/spec_files
# env: TAO_EXPERIMENT_DIR=/workspace/tao-experiments/unet
# mkdir: cannot create directory ‘/dli/task/tao_project/unet’: File exists

# %% [markdown]
# The cell below maps the project directory on your local host to a workspace directory in the TAO docker instance, so that the data and the results are mapped from in and out of the docker. This is done by creating a `.tao_mounts.json` file. For more information, please refer to the [launcher instance](https://docs.nvidia.com/tao/tao-toolkit/tao_launcher.html) in the user guide. Setting the `DockerOptions` ensures that you don't have permission issues when writing data into folders created by the TAO docker.

# %%
# DO NOT CHANGE THIS CELL
# mapping up the local directories to the TAO docker
mounts_file = os.path.expanduser("~/.tao_mounts.json")

drive_map = {
    "Mounts": [
            # Mapping the data directory
            {
                "source": os.environ["LOCAL_PROJECT_DIR"],
                "destination": "/workspace/tao-experiments"
            },
            # Mapping the specs directory.
            {
                "source": os.environ["LOCAL_SPECS_DIR"],
                "destination": os.environ["TAO_SPECS_DIR"]
            },
            # Mapping the data directory.
            {
                "source": os.environ["LOCAL_DATA_DIR"],
                "destination": os.environ["TAO_DATA_DIR"]
            },
        ],
    "DockerOptions": {
        "user": "{}:{}".format(os.getuid(), os.getgid())
    }
}

# writing the mounts file
with open(mounts_file, "w") as mfile:
    json.dump(drive_map, mfile, indent=4)

# %% [markdown]
# To see the usage of different functionality that are supported, use the `-h` or `--help` option. For more information, see the [TAO Toolkit Quick Start Guide](https://docs.nvidia.com/tao/tao-toolkit/text/tao_toolkit_quick_start_guide.html).
# Here is the **sample output**:

# %%
# DO NOT CHANGE THIS CELL
# !tao model --help
# Out:
# usage: tao model [-h]
#                  {list,stop,info,dataset,deploy,model} ...
#                  {action_recognition,centerpose,visual_changenet,deformable_detr,dino,grounding_dino,mask_grounding_dino,mask2former,mal,ml_recog,ocdnet,ocrnet,optical_inspection,pointpillars,pose_classification,re_identification,classification_pyt,segformer,bevfusion,bpnet,classification_tf1,converter,detectnet_v2,dssd,efficientdet_tf1,faster_rcnn,fpenet,lprnet,mask_rcnn,multitask_classification,retinanet,ssd,unet,yolo_v3,yolo_v4,yolo_v4_tiny,classification_tf2,efficientdet_tf2}
#                  ...
#
# options:
#   -h, --help            show this help message and exit
#
# task_groups:
#   {list,stop,info,dataset,deploy,model}
#
# task:
#   {action_recognition,centerpose,visual_changenet,deformable_detr,dino,grounding_dino,mask_grounding_dino,mask2former,mal,ml_recog,ocdnet,ocrnet,optical_inspection,pointpillars,pose_classification,re_identification,classification_pyt,segformer,bevfusion,bpnet,classification_tf1,converter,detectnet_v2,dssd,efficientdet_tf1,faster_rcnn,fpenet,lprnet,mask_rcnn,multitask_classification,retinanet,ssd,unet,yolo_v3,yolo_v4,yolo_v4_tiny,classification_tf2,efficientdet_tf2}

# %% [markdown]
# With the TAO Toolkit, users can train models for object detection, classification, segmentation, optical character recognition, facial landmark estimation, gaze estimation, and more. In TAO's terminology, these would be the **tasks**, which support **subtasks** such as `train`, `prune`, `evaluate`, `export`, etc. Each task/subtask requires different combinations of configuration files to accommodate for different parameters, such as the dataset parameters, model parameters, and optimizer and training hyperparameters. Part of what makes TAO Toolkit so easy to use is that most of those parameters are hidden away in the form of experiment specification files (spec files). They are detailed in the [documentation](https://docs.nvidia.com/tao/tao-toolkit/#tao-toolkit) for reference. It's very helpful to have these resources handy when working with the TAO Toolkit. In addition, there are several specific tasks that help with handling the launched commands.
#
# Below are the tasks available in the TAO Toolkit, organized by their respective computer vision objectives. We grayed out the tasks for Conversational AI as they are out of scope for this course.

# %% [markdown]
# <a name='s2-e1'></a>
# ### Exercise #1 - Explore TAO Toolkit CLI ###
# Let's explore some TAO Toolkit tasks.
#
# **Instructions**:<br>
# * Modify the `<FIXME>`s only and execute the cell, choosing a task from options such as: `[classification, detectnet_v2, mask_rcnn, emotionnet, etc.]`, followed by a subtask from options such as: `[calibration_tensorfile, dataset_convert, evaluate, export, inference, prune, train]`.

# %%
# Example: !tao model unet train --help
# !tao model unet train --help
# Out:
# 2025-08-05 11:27:26,916 [TAO Toolkit] [INFO] root 160: Registry: ['nvcr.io']
# 2025-08-05 11:27:27,020 [TAO Toolkit] [INFO] nvidia_tao_cli.components.instance_handler.local_instance 360: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:5.0.0-tf1.15.5
# 2025-08-05 11:27:27,033 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 301: Printing tty value True
# 2025-08-05 11:27:28.065926: I tensorflow/stream_executor/platform/default/dso_loader.cc:50] Successfully opened dynamic library libcudart.so.12
# 2025-08-05 11:27:28,119 [TAO Toolkit] [WARNING] tensorflow 40: Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# 2025-08-05 11:27:30,074 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:27:30,109 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:27:30,113 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:27:30,403 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2025-08-05 11:27:30,403 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.WARN is deprecated. Please use tf.compat.v1.logging.WARN instead.
#
# 2025-08-05 11:27:30,786 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:27:31,722 [TAO Toolkit] [INFO] matplotlib.font_manager 1633: generated new fontManager
# usage: unet train [-h] [--num_processes NUM_PROCESSES] [--gpus GPUS]
#                   [--gpu_index GPU_INDEX [GPU_INDEX ...]] [--use_amp]
#                   [--log_file LOG_FILE] [-e EXPERIMENT_SPEC_FILE]
#                   [-m PRETRAINED_MODEL_FILE] [-r RESULTS_DIR] [-n MODEL_NAME]
#                   [-v] [-k KEY]
#                   {train,prune,inference,export,evaluate,dataset_convert} ...
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --num_processes NUM_PROCESSES, -np NUM_PROCESSES
#                         The number of horovod child processes to be spawned.
#                         Default is -1(equal to --gpus).
#   --gpus GPUS           The number of GPUs to be used for the job.
#   --gpu_index GPU_INDEX [GPU_INDEX ...]
#                         The indices of the GPU's to be used.
#   --use_amp             Flag to enable Auto Mixed Precision.
#   --log_file LOG_FILE   Path to the output log file.
#   -e EXPERIMENT_SPEC_FILE, --experiment_spec_file EXPERIMENT_SPEC_FILE
#                         Path to spec file. Absolute path or relative to
#                         working directory. If not specified, default spec from
#                         spec_loader.py is used.
#   -m PRETRAINED_MODEL_FILE, --pretrained_model_file PRETRAINED_MODEL_FILE
#                         Model path to the pre-trained weights.
#   -r RESULTS_DIR, --results_dir RESULTS_DIR
#                         Path to a folder where experiment outputs should be
#                         written.
#   -n MODEL_NAME, --model_name MODEL_NAME
#                         Name of the model file. If not given, then defaults to
#                         model.tlt.
#   -v, --verbose         Set verbosity level for the logger.
#   -k KEY, --key KEY     The key to load pretrained weights and save
#                         intermediate snapshopts and final model.
#
# tasks:
#   {train,prune,inference,export,evaluate,dataset_convert}
# 2025-08-05 11:27:32,810 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 363: Stopping container.

# %% [raw]
# !tao model unet train --help

# %% [markdown]
# Click ... to show **solution**.

# %% [markdown]
# Did you get the below error message? This is likely due to a bad NGC configuration. Please check the NGC CLI and Docker Registry section of the [introduction notebook](00_introduction.ipynb).

# %% [raw]
# AssertionError: Config path must be a valid unix path. No file found at: /root/.docker/config.json. Did you run docker login?

# %% [markdown]
# <a name='s2-2'></a>
# ## U-Net Semantic Segmentation Model ##
# [U-Net](https://catalog.ngc.nvidia.com/orgs/nvidia/teams/tao/models/pretrained_semantic_segmentation) is a neural network for image segmentation. This is the type of task we want to perform for our disaster risk monitoring system in order to label each pixel as either `flood` or `notflood`. With the TAO Toolkit, we can choose the desired ResNet-18 backbone as a feature extractor. As such, we will use the `unet` task, which supports the following subtasks:
# * `train`
# * `evaluate`
# * `inference`
# * `prune`
# * `export`
#
#
# These subtasks can be invoked using the convention `tao model unet <subtask> <args_per_subtask>` on the command-line, where `args_per_subtask` are the arguments required for a given subtask. Additionally, we can always find more information about these subtasks with `tao model unet <subtask> -h` or `tao model unet <subtask> --help`.

# %% [markdown]
# ### Preparation for Model Training ###
# For the remaining of the notebook, we will use the TAO Toolkit to train a semantic segmentation model. Below is what the model development workflow looks like. We start by preparing a pre-trained model and the data. Next, we prepare the configuration file(s) and begin to train the model with new data and evaluate its performance. We will export the model once its satisfactory. Note that this notebook does not include inference optimization steps, which is important for disaster risk monitoring systems that are deployed on edge devices.

# %% [markdown]
# <a name='s2-2.2'></a>
# ### Download Pre-Trained Model ###
# Developers typically begin by choosing and downloading a pre-trained model from [NGC](https://ngc.nvidia.com/), which contains pre-trained weights of the architecture of their choice. It's difficult to immediately identify which model/architecture will work best for a specific use case as there is often a tradeoff between time to train, accuracy, and inference performance. It is common to compare across multiple models before picking the best candidate.
#
# Here are some pointers that will help choose an appropriate model:
# * Look at the model inputs/outputs to decide if it will fit your use case.
# * Input format is also an important consideration. For example, some models expect the input to be 0-1 normalized with input channels in RGB order. Some models that use a different input order may require input preprocessing/mean subtraction that might result in suboptimal performance.
#
# We can use the `ngc registry model list <model_glob_string>` command to get a list of models that are hosted on the NGC model registry. For example, we can use `ngc registry model list nvidia/tao/*` to list all available models. The `--column` option identifies the columns of interest. More information about the NGC Registry CLI can be found in the [User Guide](https://docs.nvidia.com/dgx/pdf/ngc-registry-cli-user-guide.pdf). `The ngc registry model download-version <org>/[<team>/]<model-name:version>` command will download the model from the registry. It has a `--dest` option to specify the path to download directory. Alternatively, a catalog of support models can also be found [here](https://catalog.ngc.nvidia.com/orgs/nvidia/teams/tao/collections/tao_computervision).

# %%
# DO NOT CHANGE THIS CELL
# list all available models
# !ngc registry model list nvidia/tao/pretrained_semantic_segmentation:*
# Out:
# [{
#     "accuracyReached": 82.2,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2024-02-27T11:02:45.350Z",
#     "description": "",
#     "gpuModel": "V100",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 540114376,
#     "versionId": "vgg19"
# },{
#     "accuracyReached": 77.56,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2024-02-27T11:02:12.737Z",
#     "description": "",
#     "gpuModel": "V100",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 161183816,
#     "versionId": "vgg16"
# },{
#     "accuracyReached": 77.91,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2021-08-24T13:44:52.409Z",
#     "description": "",
#     "gpuModel": "V100",
#     "memoryFootprint": "294.1976",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 308488496,
#     "versionId": "resnet50"
# },{
#     "accuracyReached": 77.04,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2021-08-24T13:45:22.007Z",
#     "description": "",
#     "gpuModel": "V100",
#     "memoryFootprint": "170.6549",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 178944632,
#     "versionId": "resnet34"
# },{
#     "accuracyReached": 76.74,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2021-08-24T13:45:42.209Z",
#     "description": "",
#     "gpuModel": "V100",
#     "memoryFootprint": "88.9573",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 93278448,
#     "versionId": "resnet18"
# },{
#     "accuracyReached": 77.78,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2021-08-24T13:45:54.627Z",
#     "description": "",
#     "gpuModel": "V100",
#     "memoryFootprint": "576.3329",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 604328880,
#     "versionId": "resnet101"
# },{
#     "accuracyReached": 74.38,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2021-08-24T13:47:01.252Z",
#     "description": "",
#     "gpuModel": "V100",
#     "memoryFootprint": "38.3121",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 40173128,
#     "versionId": "resnet10"
# },{
#     "accuracyReached": 77.11,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2021-08-24T13:47:19.420Z",
#     "description": "",
#     "gpuModel": "V100",
#     "memoryFootprint": "16.9008",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 17721744,
#     "versionId": "efficientnet_b0_swish"
# },{
#     "accuracyReached": 77.11,
#     "batchSize": 1,
#     "createdByUser": "n90fe0en2gvll5957fel7u75sg",
#     "createdDate": "2021-08-24T13:47:35.558Z",
#     "description": "",
#     "gpuModel": "V100",
#     "memoryFootprint": "16.9008",
#     "numberOfEpochs": 80,
#     "status": "UPLOAD_COMPLETE",
#     "totalFileCount": 1,
#     "totalSizeInBytes": 17721744,
#     "versionId": "efficientnet_b0_relu"
# }]

# %% [markdown]
# Did you get the below error message? This is likely due to a bad NGC CLI configuration. Please check the NGC CLI and Docker Registry section of the [introduction notebook](00_introduction.ipynb).

# %% [raw]
# {
#     "error": "Error: Invalid apikey"
# }

# %%
# DO NOT CHANGE THIS CELL
# create directory to store the pre-trained model
# !mkdir -p $LOCAL_EXPERIMENT_DIR/pretrained_resnet18/

# download the pre-trained segmentation model from NGC
# !ngc registry model download-version nvidia/tao/pretrained_semantic_segmentation:resnet18 \
    --dest $LOCAL_EXPERIMENT_DIR/pretrained_resnet18
# Out:
# {
#     "download_end": "2025-08-05 11:27:45",
#     "download_start": "2025-08-05 11:27:44",
#     "download_time": "1s",
#     "files_downloaded": 1,
#     "local_path": "/dli/task/tao_project/unet/pretrained_resnet18/pretrained_semantic_segmentation_vresnet18",
#     "size_downloaded": "88.96 MB",
#     "status": "COMPLETED"
# }

# %% [markdown]
# For this lab, we will use _ResNet18_ as the architecture for the semantic segmentation model. [Residual neural network](https://en.wikipedia.org/wiki/Residual_neural_network), or **ResNet**, is a type of convolutional neural network used as a backbone for many computer vision tasks. The `18` refers to the number of layers in this architecture. It should be noted that typically the deeper (i.e. more layers) a neural network is, the more time consuming it is to compute.

# %% [markdown]
# We designated the model to be downloaded locally to `tao_project/unet/pretrained_resnet18`, which is mapped to `/workspace/tao-experiments/unet/pretrained_resnet18` in the TAO container based on the mapping of `LOCAL_PROJECT_DIR` to `TAO_PROJECT_DIR`. Looking at the `local_path` and `transfer_id` keys of the output JSON, we can gather that the path of the pre-trained model should be in the `tao_project/unet/pretrained_resnet18/pretrained_semantic_segmentation_vresnet18 directory`. When referencing paths for the TAO Toolkit, it's important to use paths based on the TAO container. In this case it would be `/workspace/tao-experiments/unet/pretrained_resnet18/pretrained_semantic_segmentation_vresnet18`.

# %%
# DO NOT CHANGE THIS CELL
# !tree -a tao_project/unet/pretrained_resnet18
# Out:
# tao_project/unet/pretrained_resnet18
# └── pretrained_semantic_segmentation_vresnet18
#     └── resnet_18.hdf5
#
# 1 directory, 1 file

# %% [markdown]
# ### Prepare Dataset ###
# The TAO Toolkit expects the training data for the `unet` subtasks to be in the format described in the [documentation](https://docs.nvidia.com/tao/tao-toolkit/text/data_annotation_format.html#id8). Each mask image is a single-channel image, where every pixel is assigned an integer value that represents the segmentation class `label_id`, as per the mapping provided in the `dataset_config`. Additionally, each image and label have the same file ID before the extension and size. The image-to-label correspondence is maintained using this filename. The data folder structure for images and masks must be in the following format.
#
# _The `test` folder in the above directory structure is optional; any folder can be used for inference._

# %% [markdown]
# Below we will split the data into `train` set and `validation` set and copy the images into their respective folder.

# %%
# DO NOT CHANGE THIS CELL
# remove existing splits
# !rm -rf $LOCAL_DATA_DIR/images/train
# !mkdir -p $LOCAL_DATA_DIR/images/train
# !rm -rf $LOCAL_DATA_DIR/images/val
# !mkdir -p $LOCAL_DATA_DIR/images/val

# !rm -rf $LOCAL_DATA_DIR/masks/train
# !mkdir -p $LOCAL_DATA_DIR/masks/train
# !rm -rf $LOCAL_DATA_DIR/masks/val
# !mkdir -p $LOCAL_DATA_DIR/masks/val

# %%
# DO NOT CHANGE THIS CELL
# import dependencies
from random import sample
import shutil

# define split ratio
split=0.75

# get all images
file_list=os.listdir(f"{os.environ['LOCAL_DATA_DIR']}/images/all_images")
image_count=len(file_list)
train_image_list=sample(file_list, int(image_count*split))
val_image_list=[file for file in file_list if file not in train_image_list]

# move all training images to train directory
for each_file in train_image_list: 
    if each_file.split('.')[-1]=='png': 
        shutil.copyfile(f"{os.environ['LOCAL_DATA_DIR']}/images/all_images/{each_file}", f"{os.environ['LOCAL_DATA_DIR']}/images/train/{each_file}")
        shutil.copyfile(f"{os.environ['LOCAL_DATA_DIR']}/masks/all_masks/{each_file}", f"{os.environ['LOCAL_DATA_DIR']}/masks/train/{each_file}")

# move all validation images to val directory
for each_file in val_image_list: 
    if each_file.split('.')[-1]=='png': 
        shutil.copyfile(f"{os.environ['LOCAL_DATA_DIR']}/images/all_images/{each_file}", f"{os.environ['LOCAL_DATA_DIR']}/images/val/{each_file}")
        shutil.copyfile(f"{os.environ['LOCAL_DATA_DIR']}/masks/all_masks/{each_file}", f"{os.environ['LOCAL_DATA_DIR']}/masks/val/{each_file}")

# %% [markdown]
# <a name='s2-2.4'></a>
# ### Model Training ###
# Training configuration is done through a training spec file, which includes options such as which dataset to use for training, which dataset to use for validation, which pre-trained model architecture to use, which hyperparameters to tune, and other training options. The `train`, `evaluate`, `prune`, and `inference` subtasks for a U-Net experiment share the same configuration file. Configuration files can be created from scratch or modified using the templates provided in TAO Toolkit's [sample applications](https://docs.nvidia.com/tao/tao-toolkit/#cv-applications).
#
# The training configuration file has the following sections:
# * `dataset_config`
# * `model_config`
# * `training_config`

# %% [markdown]
# We will create the configuration files using templates. Specifically, we have broken the configuration files into separate parts for ease of discussion, which we will combine at the end for the TAO Toolkit to consume.

# %% [markdown]
# Execute the below cells to preview the combined training/evaluation configuration file that will be used. It is currently not usable as we have made some intentional modifications that will require correction.

# %%
# DO NOT CHANGE THIS CELL
# combining configuration components in separate files and writing into one
# !cat $LOCAL_SPECS_DIR/resnet18/dataset_config.txt \
     $LOCAL_SPECS_DIR/resnet18/model_config.txt \
     $LOCAL_SPECS_DIR/resnet18/training_config.txt \
     > $LOCAL_SPECS_DIR/resnet18/combined_config.txt
# !cat $LOCAL_SPECS_DIR/resnet18/combined_config.txt
# Out:
# dataset_config {
#   dataset: "<<<<FIXME>>>>"
#   augment: <<<<FIXME>>>>
#   augmentation_config {
#     spatial_augmentation {
#       hflip_probability : 0.5
#       vflip_probability : 0.5
#       crop_and_resize_prob : 0.5
#     }
#   }
#   input_image_type: "<<<<FIXME>>>>"
#   train_images_path: "/workspace/tao-experiments/data/<<<<FIXME>>>>"
#   train_masks_path: "/workspace/tao-experiments/data/<<<<FIXME>>>>"
#
#   val_images_path: "/workspace/tao-experiments/data/<<<<FIXME>>>>"
#   val_masks_path: "/workspace/tao-experiments/data/<<<<FIXME>>>>"
#
#   test_images_path: "/workspace/tao-experiments/data/images/val"
#
#   data_class_config {
#     target_classes {
#       name: "notflood"
#       mapping_class: "notflood"
#       label_id: 0
#     }
#     target_classes {
#       name: "flood"
#       mapping_class: "flood"
#       label_id: 255
#     }
#   }
# }
# ########## LEAVE NEW LINE BELOW
# model_config {
#   model_input_width: <<<<FIXME>>>>
#   model_input_height: <<<<FIXME>>>>
#   model_input_channels: <<<<FIXME>>>>
#   num_layers: 18
#   all_projections: true
#   arch: "resnet"
#   training_precision {
#     backend_floatx: FLOAT32
#   }
# }
# ########## LEAVE NEW LINE BELOW
#
# training_config {
#   batch_size: 1
#   epochs: <<<<FIXME>>>>
#   log_summary_steps: 10
#   checkpoint_interval: 10
#   loss: "cross_dice_sum"
#   learning_rate: 0.0001
#   regularizer {
#     type: L2
#     weight: 2e-5
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993923e-09
#       beta1: 0.899999976158
#       beta2: 0.999000012875
#     }
#   }
# }
# ########## LEAVE NEW LINE BELOW

# %% [markdown]
# Note that we must leave an empty new line at the end of each text file to ensure the `combined_config.txt` is created properly.

# %% [markdown]
# <a name='s2-e2'></a>
# ### Exercise #2 - Modify Dataset Config ###
# The dataloader defines the path of the data that the model will train on and the class mapping for the classes in the dataset. We have previously generated images and masks for the training datasets. To use the newly generated training data, update the `dataset_config` parameter in the spec file to reference the correct directory.
# * `dataset (str)`: The input type dataset used. The currently supported dataset is `custom` to the user. Open-source datasets will be added in the future.
# * `augment (bool)`: If the input should be augmented online while training. When using one’s own dataset to train and fine-tune a model, the dataset can be augmented while training to introduce variations in the dataset. This is known as **online augmentation**. This is very useful in training as data variation improves the overall quality of the model and prevents [overfitting](https://en.wikipedia.org/wiki/Overfitting). Training a deep neural network requires large amounts of annotated data, which can be a manual and expensive process. Furthermore, it can be difficult to estimate all the corner cases that the network may go through. The TAO Toolkit provides _spatial augmentation_ (resize and flip) and _color space augmentation_ (brightness) to create synthetic data variations.
# * `augmentation_config (dict)`:
#     * `spatial_augmentation (dict)`: Supports spatial augmentation such as flip, zoom, and translate.
#         * `hflip_probability (float)`: Probability to flip an input image horizontally.
#         * `vflip_probability (float)`: Probability to flip an input image vertically.
#         * `crop_and_resize_prob (float)`
#     * `brightness_augmentation (dict)`: Configures the color space transformation.
#         * `delta (float)`: Adjust brightness using delta value.
# * `input_image_type (str)`: The input image type to indicate if input image is `grayscale` or `color` (RGB).
# * `train_images_path (str)`, `train_masks_path (str)`, `val_images_path (str)`, `val_masks_path (str)`, `test_images_path (str)`: The path string for train images, train masks, validation images, validation masks, and test images (optional).
# * `data_class_config (dict)`: Proto dictionary that contains information of training classes as part of target_classes proto which is described below.
#     * `target_classes (dict)`: The repeated field for every training class. The following are required parameters for the `target_classes` config:
#         * `name (str)`: The name of the target class.
#         * `mapping_class (str)`: The name of the mapping class for the target class. If the class needs to be trained as is, then name and mapping_class should be the same.
#         * `label_id (int)`: The pixel that belongs to this target class is assigned this label_id value in the mask image.
#
# _Note the supported image extension formats for training images are “.png”, “.jpg”, “.jpeg”, “.PNG”, “.JPG”, and “.JPEG”._
#
# **Instructions**:<br>
# * Modify the `dataset_config`[(here)](tao_project/spec_files/resnet18/dataset_config.txt) section of the training configuration file by changing the `<FIXME>`s into acceptable values and **save changes**.

# %%
# DO NOT CHANGE THIS CELL
# read the config file
# !cat $LOCAL_SPECS_DIR/resnet18/dataset_config.txt
# Out:
# dataset_config {
#   dataset: "custom"
#   augment: true
#   augmentation_config {
#     spatial_augmentation {
#       hflip_probability : 0.5
#       vflip_probability : 0.5
#       crop_and_resize_prob : 0.5
#     }
#   }
#   input_image_type: "color"
#   train_images_path: "/workspace/tao-experiments/data/images/train"
#   train_masks_path: "/workspace/tao-experiments/data/masks/train"
#
#   val_images_path: "/workspace/tao-experiments/data/images/val"
#   val_masks_path: "/workspace/tao-experiments/data/masks/val"
#
#   test_images_path: "/workspace/tao-experiments/data/images/val"
#
#   data_class_config {
#     target_classes {
#       name: "notflood"
#       mapping_class: "notflood"
#       label_id: 0
#     }
#     target_classes {
#       name: "flood"
#       mapping_class: "flood"
#       label_id: 255
#     }
#   }
# }
# ########## LEAVE NEW LINE BELOW

# %% [raw]
# dataset_config {
#   dataset: "custom"
#   augment: true
#   augmentation_config {
#     spatial_augmentation {
#       hflip_probability : 0.5
#       vflip_probability : 0.5
#       crop_and_resize_prob : 0.5
#     }
#   }
#   input_image_type: "color"
#   train_images_path:"/workspace/tao-experiments/data/images/train"
#   train_masks_path:"/workspace/tao-experiments/data/masks/train"
#
#   val_images_path:"/workspace/tao-experiments/data/images/val"
#   val_masks_path:"/workspace/tao-experiments/data/masks/val"
#
#   test_images_path:"/workspace/tao-experiments/data/images/val"
#
#   data_class_config {
#     target_classes {
#       name: "notflood"
#       mapping_class: "notflood"
#       label_id: 0
#     }
#     target_classes {
#       name: "flood"
#       mapping_class: "flood"
#       label_id: 255
#     }
#   }
# }

# %% [markdown]
# Click ... to show **solution**.

# %% [markdown]
# <a name='s2-e3'></a>
# ### Exercise #3 - Modify Model Config ###
# The segmentation model can be configured using the `model_config` option in the spec file.
# * `all_projections (bool)`: For templates with shortcut connections, this parameter defines whether all shortcuts should be instantiated with 1x1 projection layers, irrespective of a change in stride across the input and output.
# * `arch (str)`: The architecture of the backbone feature extractor to be used for training.
# * `num_layers (int)`: The depth of the feature extractor for scalable templates.
# * `use_batch_norm (bool)`: A Boolean value that determines whether to use batch normalization layers or not.
# * `training_precision (dict)`: Contains a nested parameter that sets the precision of the back-end training framework.
#     * `backend_floatx`: The back-end training framework should be set to `FLOAT322`.
# * `initializer (choice)`: Initialization of convolutional layers. Supported initializations are `HE_UNIFORM`, `HE_NORMAL`, and `GLOROT_UNIFORM`.
# * `model_input_height (int)`: The model input height dimension of the model, which should be a multiple of 16.
# * `model_input_width (int)`: The model input width dimension of the model, which should be a multiple of 16.
# * `model_input_channels (int)`: The model-input channels dimension of the model, which should be set to 3 for a ResNet/VGG backbone.
#
# **Instructions**:<br>
# * Modify the `model_config`[(here)](tao_project/spec_files/resnet18/model_config.txt) section of the configuration file by changing the `<FIXME>`s into acceptable values and **save changes**.

# %%
# DO NOT CHANGE THIS CELL
# read the config file
# !cat $LOCAL_SPECS_DIR/resnet18/model_config.txt
# Out:
# model_config {
#   model_input_width: 512
#   model_input_height: 512
#   model_input_channels: 3
#   num_layers: 18
#   all_projections: true
#   arch: "resnet"
#   training_precision {
#     backend_floatx: FLOAT32
#   }
# }
# ########## LEAVE NEW LINE BELOW

# %% [raw]
# model_config {
#   model_input_width: 512
#   model_input_height: 512
#   model_input_channels: 3
#   num_layers: 18
#   all_projections: true
#   arch: "resnet"
#   training_precision {
#     backend_floatx: FLOAT32
#   }
# }

# %% [markdown]
# Click ... to show **solution**.

# %% [markdown]
# <a name='s2-e4'></a>
# #### Exercise #4 - Modify Training Config ####
# The `training_config` describes the training and learning process.
# * `batch_size (int)`: The number of images per batch per gpu.
# * `epochs (int)`: The number of epochs to train the model. One epoch represents one iteration of training through the entire dataset.
# * `log_summary_steps (int)`: The summary-steps interval at which train details are printed to stdout.
# * `checkpoint_interval (int)`: The number of epochs interval at which the checkpoint is saved.
# * `loss (str)`: The loss to be used for segmentation.
# * `learning_rate (float)`: The learning-rate initialization value.
# * `regularizer (dict)`: This parameter configures the type and weight of the regularizer to be used during training. The two parameters include:
#     * `type (Choice)`: The type of the regularizer being used should be `L2` or `L1`.
#     * `weight (Float)`: The floating-point weight of the regularizer.
# * `optimizer (dict)`: This parameter defines which optimizer to use for training, and the parameters to configure it, namely:
#     * `adam`:
#         * `epsilon (float)`: Is a very small number to prevent any division by zero in the implementation.
#         * `beta1 (float)`.
#         * `beta2 (float)`.
# * `activation (str)`: The activation to be used on the last layer supported is `softmax`.
#
# **Instructions**:<br>
# * Modify the `training_config`[(here)](tao_project/spec_files/resnet18/training_config.txt) section of the training configuration file by changing the `<FIXME>` into acceptable values and **save changes**. Typically, using a higher epochs count will improve model performance but takes longer time to complete. For the purpose of this exercise, we recommend starting with a low `n_epochs`, such as `5`, to allow the model to converge without taking too much time.

# %%
# DO NOT CHANGE THIS CELL
# read the config file
# !cat $LOCAL_SPECS_DIR/resnet18/training_config.txt
# Out:
# training_config {
#   batch_size: 1
#   epochs: 5
#   log_summary_steps: 10
#   checkpoint_interval: 10
#   loss: "cross_dice_sum"
#   learning_rate: 0.0001
#   regularizer {
#     type: L2
#     weight: 2e-5
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993923e-09
#       beta1: 0.899999976158
#       beta2: 0.999000012875
#     }
#   }
# }
# ########## LEAVE NEW LINE BELOW

# %% [raw]
# training_config {
#   batch_size: 1
#   epochs: 5
#   log_summary_steps: 5
#   checkpoint_interval: 5
#   loss: "cross_dice_sum"
#   learning_rate: 0.0001
#   regularizer {
#     type: L2
#     weight: 2e-5
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993923e-09
#       beta1: 0.899999976158
#       beta2: 0.999000012875
#     }
#   }
# }

# %% [markdown]
# Click ... to show **solution**.

# %% [markdown]
# <a name='s2-2.5'></a>
# ### Combine Configuration Files ###

# %%
# DO NOT CHANGE THIS CELL
# combining configuration components in separate files and writing into one
# !cat $LOCAL_SPECS_DIR/resnet18/dataset_config.txt \
     $LOCAL_SPECS_DIR/resnet18/model_config.txt \
     $LOCAL_SPECS_DIR/resnet18/training_config.txt \
     > $LOCAL_SPECS_DIR/resnet18/combined_config.txt
# !cat $LOCAL_SPECS_DIR/resnet18/combined_config.txt
# Out:
# dataset_config {
#   dataset: "custom"
#   augment: true
#   augmentation_config {
#     spatial_augmentation {
#       hflip_probability : 0.5
#       vflip_probability : 0.5
#       crop_and_resize_prob : 0.5
#     }
#   }
#   input_image_type: "color"
#   train_images_path: "/workspace/tao-experiments/data/images/train"
#   train_masks_path: "/workspace/tao-experiments/data/masks/train"
#
#   val_images_path: "/workspace/tao-experiments/data/images/val"
#   val_masks_path: "/workspace/tao-experiments/data/masks/val"
#
#   test_images_path: "/workspace/tao-experiments/data/images/val"
#
#   data_class_config {
#     target_classes {
#       name: "notflood"
#       mapping_class: "notflood"
#       label_id: 0
#     }
#     target_classes {
#       name: "flood"
#       mapping_class: "flood"
#       label_id: 255
#     }
#   }
# }
# ########## LEAVE NEW LINE BELOW
# model_config {
#   model_input_width: 512
#   model_input_height: 512
#   model_input_channels: 3
#   num_layers: 18
#   all_projections: true
#   arch: "resnet"
#   training_precision {
#     backend_floatx: FLOAT32
#   }
# }
# ########## LEAVE NEW LINE BELOW
#
# training_config {
#   batch_size: 1
#   epochs: 5
#   log_summary_steps: 10
#   checkpoint_interval: 10
#   loss: "cross_dice_sum"
#   learning_rate: 0.0001
#   regularizer {
#     type: L2
#     weight: 2e-5
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993923e-09
#       beta1: 0.899999976158
#       beta2: 0.999000012875
#     }
#   }
# }
# ########## LEAVE NEW LINE BELOW

# %% [markdown]
# <a name='s2-2.6'></a>
# ### Initiate Model Training ###
# After preparing input data and setting up a spec file, we can start training the semantic segmentation model.

# %% [raw]
# tao model unet train [-h] -e <EXPERIMENT_SPEC_FILE>
#                           -r <RESULTS_DIR>
#                           -n <MODEL_NAME>
#                           -m <PRETRAINED_MODEL_FILE>
#                           -k <key>
#                           [-v Set Verbosity of the logger]
#                           [--gpus GPUS]
#                           [--gpu_index GPU_INDEX]

# %% [markdown]
# When using the `train` subtask, the `-e` argument indicates the path to the spec file, the `-r` argument indicates the result directory, and the `-k` indicates the key to _load_ the pre-trained weights. There are some arguments that might be useful such as `-n` to indicates the name of the final step model saved and `-m` to indicate the path to a pre-trained model to initialize. Based on how NGC names the model downloaded, we should use `/workspace/tao-experiments/unt/pretrained_resnet18/pretrained_semantic_segmentation_vresnet18/resnet_18.hdf5` to reference the pre-trained model.
#
# _Multi-GPU support can be enabled for those with the hardware using the `--gpus` argument. When running the training with more than one GPU, we will need to modify the `batch_size` and `learning_rate`. In most cases, scaling down the batch-size by a factor of NUM_GPU's or scaling up the learning rate by a factor of NUM_GPUs would be a good place to start._

# %%
# DO NOT CHANGE THIS CELL
# remove any previous training if exists
# !rm -rf $LOCAL_EXPERIMENT_DIR/resnet18

# %% [markdown]
# While the TAO Toolkit is running, there may be some _TensorFlow deprecation_ warning messages that can be ignored.

# %%
# DO NOT CHANGE THIS CELL
# train model
# !tao model unet train -e $TAO_SPECS_DIR/resnet18/combined_config.txt \
                      -r $TAO_EXPERIMENT_DIR/resnet18 \
                      -n resnet18 \
                      -m $TAO_EXPERIMENT_DIR/pretrained_resnet18/pretrained_semantic_segmentation_vresnet18/resnet_18.hdf5 \
                      -k $KEY
# Out:
# 2025-08-05 11:34:00,976 [TAO Toolkit] [INFO] root 160: Registry: ['nvcr.io']
# 2025-08-05 11:34:01,077 [TAO Toolkit] [INFO] nvidia_tao_cli.components.instance_handler.local_instance 360: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:5.0.0-tf1.15.5
# 2025-08-05 11:34:01,090 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 301: Printing tty value True
# 2025-08-05 11:34:01.791832: I tensorflow/stream_executor/platform/default/dso_loader.cc:50] Successfully opened dynamic library libcudart.so.12
# 2025-08-05 11:34:01,846 [TAO Toolkit] [WARNING] tensorflow 40: Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# 2025-08-05 11:34:03,671 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:34:03,716 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:34:03,720 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:34:04,032 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2025-08-05 11:34:04,032 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.WARN is deprecated. Please use tf.compat.v1.logging.WARN instead.
#
# 2025-08-05 11:34:04,411 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:34:05,074 [TAO Toolkit] [INFO] matplotlib.font_manager 1633: generated new fontManager
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# WARNING:tensorflow:TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:34:07,328 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:34:07,359 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:34:07,362 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2025-08-05 11:34:07,637 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.WARN is deprecated. Please use tf.compat.v1.logging.WARN instead.
#
# 2025-08-05 11:34:07,637 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.WARN is deprecated. Please use tf.compat.v1.logging.WARN instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/train.py:535: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:34:08,476 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/train.py:535: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:34:08,477 [TAO Toolkit] [INFO] root 2102: Starting UNet Training job
# Loading experiment spec at /workspace/tao-experiments/spec_files/resnet18/combined_config.txt.
# 2025-08-05 11:34:08,477 [TAO Toolkit] [INFO] __main__ 349: Loading experiment spec at /workspace/tao-experiments/spec_files/resnet18/combined_config.txt.
# 2025-08-05 11:34:08,478 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.spec_handler.spec_loader 59: Merging specification from /workspace/tao-experiments/spec_files/resnet18/combined_config.txt
# 2025-08-05 11:34:08,480 [TAO Toolkit] [INFO] root 2082: Initializing the pre-trained weights from /workspace/tao-experiments/unet/pretrained_resnet18/pretrained_semantic_segmentation_vresnet18/resnet_18.hdf5
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/model/utilities.py:351: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# 2025-08-05 11:34:08,480 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/model/utilities.py:351: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/model/utilities.py:356: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# 2025-08-05 11:34:08,484 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/model/utilities.py:356: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2025-08-05 11:34:08,489 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2025-08-05 11:34:08,489 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2025-08-05 11:34:08,490 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2025-08-05 11:34:08,513 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2025-08-05 11:34:08,538 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2025-08-05 11:34:08,539 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-08-05 11:34:08,540 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-08-05 11:34:08,541 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 0: Train Id 0
# 2025-08-05 11:34:08,541 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 255: Train Id 1
#
# Phase train: Total 334 files.
# 2025-08-05 11:34:08,559 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 469: The total number of training samples 334 and the batch size per                 GPU 1
# 2025-08-05 11:34:08,559 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 485: Steps per epoch taken: 334
# INFO:tensorflow:Using config: {'_model_dir': '/workspace/tao-experiments/unet/resnet18', '_tf_random_seed': None, '_save_summary_steps': None, '_save_checkpoints_steps': None, '_save_checkpoints_secs': None, '_session_config': intra_op_parallelism_threads: 1
# inter_op_parallelism_threads: 38
# gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
#   force_gpu_compatible: true
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': None, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f316c082160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 2025-08-05 11:34:08,559 [TAO Toolkit] [INFO] tensorflow 212: Using config: {'_model_dir': '/workspace/tao-experiments/unet/resnet18', '_tf_random_seed': None, '_save_summary_steps': None, '_save_checkpoints_steps': None, '_save_checkpoints_secs': None, '_session_config': intra_op_parallelism_threads: 1
# inter_op_parallelism_threads: 38
# gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
#   force_gpu_compatible: true
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': None, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f316c082160>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 2025-08-05 11:34:08,559 [TAO Toolkit] [INFO] root 2102: Running training loop.
# Running for 5 Epochs
# 2025-08-05 11:34:08,560 [TAO Toolkit] [INFO] __main__ 91: Running for 5 Epochs
# INFO:tensorflow:Create CheckpointSaverHook.
# 2025-08-05 11:34:08,560 [TAO Toolkit] [INFO] tensorflow 541: Create CheckpointSaverHook.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2025-08-05 11:34:08,598 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# 2025-08-05 11:34:08,856 [TAO Toolkit] [WARNING] tensorflow 50:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# /usr/local/lib/python3.8/dist-packages/third_party/keras/tensorflow_backend.py:367: UserWarning: Creating resources inside a function passed to Dataset.map() is not supported. Create each resource outside the function, and capture it inside the function to use it.
#   return old_map(
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# 2025-08-05 11:34:09,191 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# 2025-08-05 11:34:09,192 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_pad is deprecated. Please use tf.compat.v1.image.resize_image_with_pad instead.
#
# 2025-08-05 11:34:09,192 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_pad is deprecated. Please use tf.compat.v1.image.resize_image_with_pad instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2025-08-05 11:34:09,827 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# 2025-08-05 11:34:10,505 [TAO Toolkit] [WARNING] tensorflow 1776: The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# INFO:tensorflow:Calling model_fn.
# 2025-08-05 11:34:11,095 [TAO Toolkit] [INFO] tensorflow 1148: Calling model_fn.
# 2025-08-05 11:34:11,095 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.utils.model_fn 196: {'exec_mode': 'train', 'model_dir': '/workspace/tao-experiments/unet/resnet18', 'resize_padding': False, 'resize_method': 'BILINEAR', 'log_dir': None, 'batch_size': 1, 'learning_rate': 9.999999747378752e-05, 'activation': 'softmax', 'crossvalidation_idx': None, 'max_steps': 1670, 'regularizer_type': 2, 'weight_decay': 1.9999999494757503e-05, 'log_summary_steps': 10, 'warmup_steps': 0, 'augment': True, 'use_amp': False, 'filter_data': False, 'use_trt': False, 'use_xla': False, 'loss': 'cross_dice_sum', 'epochs': 5, 'pretrained_weights_file': None, 'lr_scheduler': None, 'unet_model': <nvidia_tao_tf1.cv.unet.model.resnet_unet.ResnetUnet object at 0x7f3148514f40>, 'key': 'my_model_key', 'experiment_spec': dataset_config {
#   augment: true
#   dataset: "custom"
#   input_image_type: "color"
#   train_images_path: "/workspace/tao-experiments/data/images/train"
#   train_masks_path: "/workspace/tao-experiments/data/masks/train"
#   val_images_path: "/workspace/tao-experiments/data/images/val"
#   val_masks_path: "/workspace/tao-experiments/data/masks/val"
#   test_images_path: "/workspace/tao-experiments/data/images/val"
#   data_class_config {
#     target_classes {
#       name: "notflood"
#       mapping_class: "notflood"
#     }
#     target_classes {
#       name: "flood"
#       label_id: 255
#       mapping_class: "flood"
#     }
#   }
#   augmentation_config {
#     spatial_augmentation {
#       hflip_probability: 0.5
#       vflip_probability: 0.5
#       crop_and_resize_prob: 0.5
#     }
#   }
# }
# model_config {
#   num_layers: 18
#   training_precision {
#     backend_floatx: FLOAT32
#   }
#   arch: "resnet"
#   all_projections: true
#   model_input_height: 512
#   model_input_width: 512
#   model_input_channels: 3
# }
# training_config {
#   batch_size: 1
#   regularizer {
#     type: L2
#     weight: 1.9999999494757503e-05
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993922529e-09
#       beta1: 0.8999999761581421
#       beta2: 0.9990000128746033
#     }
#   }
#   checkpoint_interval: 10
#   log_summary_steps: 10
#   learning_rate: 9.999999747378752e-05
#   loss: "cross_dice_sum"
#   epochs: 5
# }
# , 'seed': 0, 'benchmark': False, 'temp_dir': '/tmp/tmp8qbhzk11', 'num_classes': 2, 'num_conf_mat_classes': 2, 'start_step': 0, 'checkpoint_interval': 10, 'model_json': None, 'custom_objs': {}, 'load_graph': False, 'remove_head': False, 'buffer_size': None, 'data_options': False, 'weights_monitor': False, 'visualize': False, 'save_summary_steps': 1, 'infrequent_save_summary_steps': 334, 'enable_qat': False, 'phase': 'train', 'steps_per_epoch': 334}
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2025-08-05 11:34:11,095 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 512, 512)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 256, 256) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 256, 256) 0           conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        activation_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 128, 128) 0           block_1a_conv_2[0][0]
#                                                                  block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 128, 128) 0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 128, 128) 0           block_1b_conv_2[0][0]
#                                                                  block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 128, 128) 0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 64, 64)  73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 64, 64)  8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 64, 64)  0           block_2a_conv_2[0][0]
#                                                                  block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 64, 64)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (None, 128, 64, 64)  16512       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 64, 64)  0           block_2b_conv_2[0][0]
#                                                                  block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 64, 64)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 32, 32)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 32, 32)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 32, 32)  0           block_3a_conv_2[0][0]
#                                                                  block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 32, 32)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (None, 256, 32, 32)  65792       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 32, 32)  0           block_3b_conv_2[0][0]
#                                                                  block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 32, 32)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 32, 32)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 32, 32)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 32, 32)  0           block_4a_conv_2[0][0]
#                                                                  block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 32, 32)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (None, 512, 32, 32)  262656      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 32, 32)  0           block_4b_conv_2[0][0]
#                                                                  block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 32, 32)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 64, 64)  2097408     block_4b_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384, 64, 64)  0           conv2d_transpose_1[0][0]
#                                                                  block_2b_relu[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 384, 64, 64)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 64, 64)  884992      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 64, 64)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 524416      activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 192, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  block_1b_relu[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 192, 128, 128 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 221312      activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 256, 256) 131136      activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 256, 256 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 256, 256 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 256, 256) 73792       activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 256, 256) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 512, 512) 65600       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 512, 512) 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 512, 512) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 512, 512) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 512, 512)  1154        activation_9[0][0]
# ==================================================================================================
# Total params: 15,561,730
# Trainable params: 15,561,730
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Done calling model_fn.
# 2025-08-05 11:34:12,506 [TAO Toolkit] [INFO] tensorflow 1150: Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# 2025-08-05 11:34:13,330 [TAO Toolkit] [INFO] tensorflow 240: Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# 2025-08-05 11:34:14,336 [TAO Toolkit] [INFO] tensorflow 500: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2025-08-05 11:34:14,394 [TAO Toolkit] [INFO] tensorflow 502: Done running local_init_op.
# [GPU] Restoring pretrained weights from: /tmp/tmpwwwowfgw/model.ckpt
# 2025-08-05 11:34:14,894 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.hooks.pretrained_restore_hook 237: Pretrained weights loaded with success...
#
# INFO:tensorflow:Saving checkpoints for step-0.
# 2025-08-05 11:34:16,839 [TAO Toolkit] [INFO] tensorflow 76: Saving checkpoints for step-0.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/training_hook.py:121: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# 2025-08-05 11:34:17,587 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/training_hook.py:121: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# 2025-08-05 11:34:25,088 [TAO Toolkit] [INFO] root 2102: None
# Epoch: 0.000000/5:, Cur-Step: 0, loss(cross_dice_sum): 1.09115, Running average loss:1.09115, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:25,088 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.000000/5:, Cur-Step: 0, loss(cross_dice_sum): 1.09115, Running average loss:1.09115, Time taken: 0 ETA: 0.0
# Epoch: 0.029940/5:, Cur-Step: 10, loss(cross_dice_sum): 0.98622, Running average loss:1.05248, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:32,641 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.029940/5:, Cur-Step: 10, loss(cross_dice_sum): 0.98622, Running average loss:1.05248, Time taken: 0 ETA: 0.0
# Epoch: 0.059880/5:, Cur-Step: 20, loss(cross_dice_sum): 0.09891, Running average loss:0.76826, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:34,712 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.059880/5:, Cur-Step: 20, loss(cross_dice_sum): 0.09891, Running average loss:0.76826, Time taken: 0 ETA: 0.0
# Epoch: 0.089820/5:, Cur-Step: 30, loss(cross_dice_sum): 0.77839, Running average loss:0.89964, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:36,760 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.089820/5:, Cur-Step: 30, loss(cross_dice_sum): 0.77839, Running average loss:0.89964, Time taken: 0 ETA: 0.0
# Epoch: 0.119760/5:, Cur-Step: 40, loss(cross_dice_sum): 0.73866, Running average loss:0.88108, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:38,816 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.119760/5:, Cur-Step: 40, loss(cross_dice_sum): 0.73866, Running average loss:0.88108, Time taken: 0 ETA: 0.0
# Epoch: 0.149701/5:, Cur-Step: 50, loss(cross_dice_sum): 0.23173, Running average loss:0.83313, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:40,877 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.149701/5:, Cur-Step: 50, loss(cross_dice_sum): 0.23173, Running average loss:0.83313, Time taken: 0 ETA: 0.0
# Epoch: 0.179641/5:, Cur-Step: 60, loss(cross_dice_sum): 0.13182, Running average loss:0.76808, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:42,942 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.179641/5:, Cur-Step: 60, loss(cross_dice_sum): 0.13182, Running average loss:0.76808, Time taken: 0 ETA: 0.0
# Epoch: 0.209581/5:, Cur-Step: 70, loss(cross_dice_sum): 0.19327, Running average loss:0.71432, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:45,013 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.209581/5:, Cur-Step: 70, loss(cross_dice_sum): 0.19327, Running average loss:0.71432, Time taken: 0 ETA: 0.0
# Epoch: 0.239521/5:, Cur-Step: 80, loss(cross_dice_sum): 0.14071, Running average loss:0.65724, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:47,068 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.239521/5:, Cur-Step: 80, loss(cross_dice_sum): 0.14071, Running average loss:0.65724, Time taken: 0 ETA: 0.0
# Epoch: 0.269461/5:, Cur-Step: 90, loss(cross_dice_sum): 0.26874, Running average loss:0.63479, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:49,129 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.269461/5:, Cur-Step: 90, loss(cross_dice_sum): 0.26874, Running average loss:0.63479, Time taken: 0 ETA: 0.0
# Epoch: 0.299401/5:, Cur-Step: 100, loss(cross_dice_sum): 1.37931, Running average loss:0.62405, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:51,190 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.299401/5:, Cur-Step: 100, loss(cross_dice_sum): 1.37931, Running average loss:0.62405, Time taken: 0 ETA: 0.0
# Epoch: 0.329341/5:, Cur-Step: 110, loss(cross_dice_sum): 0.22327, Running average loss:0.59734, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:53,276 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.329341/5:, Cur-Step: 110, loss(cross_dice_sum): 0.22327, Running average loss:0.59734, Time taken: 0 ETA: 0.0
# Epoch: 0.359281/5:, Cur-Step: 120, loss(cross_dice_sum): 0.24293, Running average loss:0.56801, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:55,377 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.359281/5:, Cur-Step: 120, loss(cross_dice_sum): 0.24293, Running average loss:0.56801, Time taken: 0 ETA: 0.0
# Epoch: 0.389222/5:, Cur-Step: 130, loss(cross_dice_sum): 0.08334, Running average loss:0.53949, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:57,436 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.389222/5:, Cur-Step: 130, loss(cross_dice_sum): 0.08334, Running average loss:0.53949, Time taken: 0 ETA: 0.0
# Epoch: 0.419162/5:, Cur-Step: 140, loss(cross_dice_sum): 0.37468, Running average loss:0.51534, Time taken: 0 ETA: 0.0
# 2025-08-05 11:34:59,507 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.419162/5:, Cur-Step: 140, loss(cross_dice_sum): 0.37468, Running average loss:0.51534, Time taken: 0 ETA: 0.0
# Epoch: 0.449102/5:, Cur-Step: 150, loss(cross_dice_sum): 0.11914, Running average loss:0.51768, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:01,572 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.449102/5:, Cur-Step: 150, loss(cross_dice_sum): 0.11914, Running average loss:0.51768, Time taken: 0 ETA: 0.0
# Epoch: 0.479042/5:, Cur-Step: 160, loss(cross_dice_sum): 0.19030, Running average loss:0.51697, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:03,634 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.479042/5:, Cur-Step: 160, loss(cross_dice_sum): 0.19030, Running average loss:0.51697, Time taken: 0 ETA: 0.0
# Epoch: 0.508982/5:, Cur-Step: 170, loss(cross_dice_sum): 0.12440, Running average loss:0.50448, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:05,693 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.508982/5:, Cur-Step: 170, loss(cross_dice_sum): 0.12440, Running average loss:0.50448, Time taken: 0 ETA: 0.0
# Epoch: 0.538922/5:, Cur-Step: 180, loss(cross_dice_sum): 0.25890, Running average loss:0.49220, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:07,767 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.538922/5:, Cur-Step: 180, loss(cross_dice_sum): 0.25890, Running average loss:0.49220, Time taken: 0 ETA: 0.0
# Epoch: 0.568862/5:, Cur-Step: 190, loss(cross_dice_sum): 0.59204, Running average loss:0.49462, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:09,835 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.568862/5:, Cur-Step: 190, loss(cross_dice_sum): 0.59204, Running average loss:0.49462, Time taken: 0 ETA: 0.0
# Epoch: 0.598802/5:, Cur-Step: 200, loss(cross_dice_sum): 0.13527, Running average loss:0.47982, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:11,887 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.598802/5:, Cur-Step: 200, loss(cross_dice_sum): 0.13527, Running average loss:0.47982, Time taken: 0 ETA: 0.0
# Epoch: 0.628743/5:, Cur-Step: 210, loss(cross_dice_sum): 0.11124, Running average loss:0.47594, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:13,940 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.628743/5:, Cur-Step: 210, loss(cross_dice_sum): 0.11124, Running average loss:0.47594, Time taken: 0 ETA: 0.0
# Epoch: 0.658683/5:, Cur-Step: 220, loss(cross_dice_sum): 0.21639, Running average loss:0.48076, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:16,004 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.658683/5:, Cur-Step: 220, loss(cross_dice_sum): 0.21639, Running average loss:0.48076, Time taken: 0 ETA: 0.0
# Epoch: 0.688623/5:, Cur-Step: 230, loss(cross_dice_sum): 0.65290, Running average loss:0.47507, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:18,075 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.688623/5:, Cur-Step: 230, loss(cross_dice_sum): 0.65290, Running average loss:0.47507, Time taken: 0 ETA: 0.0
# Epoch: 0.718563/5:, Cur-Step: 240, loss(cross_dice_sum): 0.26858, Running average loss:0.46892, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:20,136 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.718563/5:, Cur-Step: 240, loss(cross_dice_sum): 0.26858, Running average loss:0.46892, Time taken: 0 ETA: 0.0
# Epoch: 0.748503/5:, Cur-Step: 250, loss(cross_dice_sum): 0.15507, Running average loss:0.46398, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:22,198 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.748503/5:, Cur-Step: 250, loss(cross_dice_sum): 0.15507, Running average loss:0.46398, Time taken: 0 ETA: 0.0
# Epoch: 0.778443/5:, Cur-Step: 260, loss(cross_dice_sum): 0.47180, Running average loss:0.47146, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:24,253 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.778443/5:, Cur-Step: 260, loss(cross_dice_sum): 0.47180, Running average loss:0.47146, Time taken: 0 ETA: 0.0
# Epoch: 0.808383/5:, Cur-Step: 270, loss(cross_dice_sum): 0.56421, Running average loss:0.47031, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:26,350 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.808383/5:, Cur-Step: 270, loss(cross_dice_sum): 0.56421, Running average loss:0.47031, Time taken: 0 ETA: 0.0
# Epoch: 0.838323/5:, Cur-Step: 280, loss(cross_dice_sum): 0.55434, Running average loss:0.47074, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:28,417 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.838323/5:, Cur-Step: 280, loss(cross_dice_sum): 0.55434, Running average loss:0.47074, Time taken: 0 ETA: 0.0
# Epoch: 0.868263/5:, Cur-Step: 290, loss(cross_dice_sum): 0.17462, Running average loss:0.47701, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:30,481 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.868263/5:, Cur-Step: 290, loss(cross_dice_sum): 0.17462, Running average loss:0.47701, Time taken: 0 ETA: 0.0
# Epoch: 0.898204/5:, Cur-Step: 300, loss(cross_dice_sum): 0.13727, Running average loss:0.47574, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:32,551 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.898204/5:, Cur-Step: 300, loss(cross_dice_sum): 0.13727, Running average loss:0.47574, Time taken: 0 ETA: 0.0
# Epoch: 0.928144/5:, Cur-Step: 310, loss(cross_dice_sum): 0.11994, Running average loss:0.47283, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:34,632 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.928144/5:, Cur-Step: 310, loss(cross_dice_sum): 0.11994, Running average loss:0.47283, Time taken: 0 ETA: 0.0
# Epoch: 0.958084/5:, Cur-Step: 320, loss(cross_dice_sum): 0.13290, Running average loss:0.47383, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:36,690 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.958084/5:, Cur-Step: 320, loss(cross_dice_sum): 0.13290, Running average loss:0.47383, Time taken: 0 ETA: 0.0
# Epoch: 0.988024/5:, Cur-Step: 330, loss(cross_dice_sum): 0.04420, Running average loss:0.47045, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:38,737 [TAO Toolkit] [INFO] __main__ 161: Epoch: 0.988024/5:, Cur-Step: 330, loss(cross_dice_sum): 0.04420, Running average loss:0.47045, Time taken: 0 ETA: 0.0
# 2025-08-05 11:35:39,733 [TAO Toolkit] [INFO] root 2102: None
# Epoch: 1.017964/5:, Cur-Step: 340, loss(cross_dice_sum): 0.07688, Running average loss:0.20776, Time taken: 90.96940755844116 ETA: 362.2434492596609
# 2025-08-05 11:35:40,964 [TAO Toolkit] [INFO] __main__ 161: Epoch: 1.017964/5:, Cur-Step: 340, loss(cross_dice_sum): 0.07688, Running average loss:0.20776, Time taken: 90.96940755844116 ETA: 362.2434492596609
# Epoch: 1.047904/5:, Cur-Step: 350, loss(cross_dice_sum): 0.15773, Running average loss:0.35751, Time taken: 90.96940755844116 ETA: 359.5198143028214
# 2025-08-05 11:35:43,020 [TAO Toolkit] [INFO] __main__ 161: Epoch: 1.047904/5:, Cur-Step: 350, loss(cross_dice_sum): 0.15773, Running average loss:0.35751, Time taken: 90.96940755844116 ETA: 359.5198143028214
# Epoch: 1.077844/5:, Cur-Step: 360, loss(cross_dice_sum): 0.62434, Running average loss:0.45794, Time taken: 90.96940755844116 ETA: 356.7961793459818
# 2025-08-05 11:35:45,102 [TAO Toolkit] [INFO] __main__ 161: Epoch: 1.077844/5:, Cur-Step: 360, loss(cross_dice_sum): 0.62434, Running average loss:0.45794, Time taken: 90.96940755844116 ETA: 356.7961793459818
# ...
# Epoch: 3.772455/5:, Cur-Step: 1260, loss(cross_dice_sum): 0.22130, Running average loss:0.28826, Time taken: 69.77831268310547 ETA: 85.65601257506957
# 2025-08-05 11:38:52,632 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.772455/5:, Cur-Step: 1260, loss(cross_dice_sum): 0.22130, Running average loss:0.28826, Time taken: 69.77831268310547 ETA: 85.65601257506957
# Epoch: 3.802395/5:, Cur-Step: 1270, loss(cross_dice_sum): 0.06195, Running average loss:0.28755, Time taken: 69.77831268310547 ETA: 83.56684153665326
# 2025-08-05 11:38:54,705 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.802395/5:, Cur-Step: 1270, loss(cross_dice_sum): 0.06195, Running average loss:0.28755, Time taken: 69.77831268310547 ETA: 83.56684153665326
# Epoch: 3.832335/5:, Cur-Step: 1280, loss(cross_dice_sum): 0.10588, Running average loss:0.28705, Time taken: 69.77831268310547 ETA: 81.47767049823692
# 2025-08-05 11:38:56,780 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.832335/5:, Cur-Step: 1280, loss(cross_dice_sum): 0.10588, Running average loss:0.28705, Time taken: 69.77831268310547 ETA: 81.47767049823692
# Epoch: 3.862275/5:, Cur-Step: 1290, loss(cross_dice_sum): 0.39522, Running average loss:0.28609, Time taken: 69.77831268310547 ETA: 79.38849945982058
# 2025-08-05 11:38:58,865 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.862275/5:, Cur-Step: 1290, loss(cross_dice_sum): 0.39522, Running average loss:0.28609, Time taken: 69.77831268310547 ETA: 79.38849945982058
# Epoch: 3.892216/5:, Cur-Step: 1300, loss(cross_dice_sum): 0.29058, Running average loss:0.28507, Time taken: 69.77831268310547 ETA: 77.29932842140427
# 2025-08-05 11:39:00,939 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.892216/5:, Cur-Step: 1300, loss(cross_dice_sum): 0.29058, Running average loss:0.28507, Time taken: 69.77831268310547 ETA: 77.29932842140427
# Epoch: 3.922156/5:, Cur-Step: 1310, loss(cross_dice_sum): 0.10515, Running average loss:0.28684, Time taken: 69.77831268310547 ETA: 75.21015738298793
# 2025-08-05 11:39:03,014 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.922156/5:, Cur-Step: 1310, loss(cross_dice_sum): 0.10515, Running average loss:0.28684, Time taken: 69.77831268310547 ETA: 75.21015738298793
# Epoch: 3.952096/5:, Cur-Step: 1320, loss(cross_dice_sum): 0.12850, Running average loss:0.28596, Time taken: 69.77831268310547 ETA: 73.12098634457159
# 2025-08-05 11:39:05,286 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.952096/5:, Cur-Step: 1320, loss(cross_dice_sum): 0.12850, Running average loss:0.28596, Time taken: 69.77831268310547 ETA: 73.12098634457159
# Epoch: 3.982036/5:, Cur-Step: 1330, loss(cross_dice_sum): 0.19302, Running average loss:0.28310, Time taken: 69.77831268310547 ETA: 71.03181530615525
# 2025-08-05 11:39:07,374 [TAO Toolkit] [INFO] __main__ 161: Epoch: 3.982036/5:, Cur-Step: 1330, loss(cross_dice_sum): 0.19302, Running average loss:0.28310, Time taken: 69.77831268310547 ETA: 71.03181530615525
# 2025-08-05 11:39:08,643 [TAO Toolkit] [INFO] root 2102: None
# Epoch: 4.011976/5:, Cur-Step: 1340, loss(cross_dice_sum): 0.20545, Running average loss:0.27261, Time taken: 69.9285786151886 ETA: 69.09111060782108
# 2025-08-05 11:39:09,479 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.011976/5:, Cur-Step: 1340, loss(cross_dice_sum): 0.20545, Running average loss:0.27261, Time taken: 69.9285786151886 ETA: 69.09111060782108
# Epoch: 4.041916/5:, Cur-Step: 1350, loss(cross_dice_sum): 0.22038, Running average loss:0.30215, Time taken: 69.9285786151886 ETA: 66.99744058940222
# 2025-08-05 11:39:11,562 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.041916/5:, Cur-Step: 1350, loss(cross_dice_sum): 0.22038, Running average loss:0.30215, Time taken: 69.9285786151886 ETA: 66.99744058940222
# Epoch: 4.071856/5:, Cur-Step: 1360, loss(cross_dice_sum): 0.10474, Running average loss:0.29288, Time taken: 69.9285786151886 ETA: 64.90377057098343
# 2025-08-05 11:39:13,652 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.071856/5:, Cur-Step: 1360, loss(cross_dice_sum): 0.10474, Running average loss:0.29288, Time taken: 69.9285786151886 ETA: 64.90377057098343
# Epoch: 4.101796/5:, Cur-Step: 1370, loss(cross_dice_sum): 0.18801, Running average loss:0.29252, Time taken: 69.9285786151886 ETA: 62.81010055256462
# 2025-08-05 11:39:15,727 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.101796/5:, Cur-Step: 1370, loss(cross_dice_sum): 0.18801, Running average loss:0.29252, Time taken: 69.9285786151886 ETA: 62.81010055256462
# Epoch: 4.131737/5:, Cur-Step: 1380, loss(cross_dice_sum): 0.44941, Running average loss:0.31502, Time taken: 69.9285786151886 ETA: 60.716430534145765
# 2025-08-05 11:39:17,813 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.131737/5:, Cur-Step: 1380, loss(cross_dice_sum): 0.44941, Running average loss:0.31502, Time taken: 69.9285786151886 ETA: 60.716430534145765
# Epoch: 4.161677/5:, Cur-Step: 1390, loss(cross_dice_sum): 0.15522, Running average loss:0.29686, Time taken: 69.9285786151886 ETA: 58.622760515726966
# 2025-08-05 11:39:19,899 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.161677/5:, Cur-Step: 1390, loss(cross_dice_sum): 0.15522, Running average loss:0.29686, Time taken: 69.9285786151886 ETA: 58.622760515726966
# Epoch: 4.191617/5:, Cur-Step: 1400, loss(cross_dice_sum): 0.14991, Running average loss:0.28831, Time taken: 69.9285786151886 ETA: 56.52909049730817
# 2025-08-05 11:39:21,974 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.191617/5:, Cur-Step: 1400, loss(cross_dice_sum): 0.14991, Running average loss:0.28831, Time taken: 69.9285786151886 ETA: 56.52909049730817
# Epoch: 4.221557/5:, Cur-Step: 1410, loss(cross_dice_sum): 0.13486, Running average loss:0.28116, Time taken: 69.9285786151886 ETA: 54.435420478889306
# 2025-08-05 11:39:24,057 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.221557/5:, Cur-Step: 1410, loss(cross_dice_sum): 0.13486, Running average loss:0.28116, Time taken: 69.9285786151886 ETA: 54.435420478889306
# Epoch: 4.251497/5:, Cur-Step: 1420, loss(cross_dice_sum): 0.04366, Running average loss:0.27165, Time taken: 69.9285786151886 ETA: 52.34175046047051
# 2025-08-05 11:39:26,151 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.251497/5:, Cur-Step: 1420, loss(cross_dice_sum): 0.04366, Running average loss:0.27165, Time taken: 69.9285786151886 ETA: 52.34175046047051
# Epoch: 4.281437/5:, Cur-Step: 1430, loss(cross_dice_sum): 0.14470, Running average loss:0.26902, Time taken: 69.9285786151886 ETA: 50.24808044205171
# 2025-08-05 11:39:28,222 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.281437/5:, Cur-Step: 1430, loss(cross_dice_sum): 0.14470, Running average loss:0.26902, Time taken: 69.9285786151886 ETA: 50.24808044205171
# Epoch: 4.311377/5:, Cur-Step: 1440, loss(cross_dice_sum): 3.15273, Running average loss:0.28979, Time taken: 69.9285786151886 ETA: 48.154410423632854
# 2025-08-05 11:39:30,300 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.311377/5:, Cur-Step: 1440, loss(cross_dice_sum): 3.15273, Running average loss:0.28979, Time taken: 69.9285786151886 ETA: 48.154410423632854
# Epoch: 4.341317/5:, Cur-Step: 1450, loss(cross_dice_sum): 0.21300, Running average loss:0.30240, Time taken: 69.9285786151886 ETA: 46.060740405214055
# 2025-08-05 11:39:32,388 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.341317/5:, Cur-Step: 1450, loss(cross_dice_sum): 0.21300, Running average loss:0.30240, Time taken: 69.9285786151886 ETA: 46.060740405214055
# Epoch: 4.371257/5:, Cur-Step: 1460, loss(cross_dice_sum): 0.13547, Running average loss:0.29848, Time taken: 69.9285786151886 ETA: 43.96707038679526
# 2025-08-05 11:39:34,469 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.371257/5:, Cur-Step: 1460, loss(cross_dice_sum): 0.13547, Running average loss:0.29848, Time taken: 69.9285786151886 ETA: 43.96707038679526
# Epoch: 4.401198/5:, Cur-Step: 1470, loss(cross_dice_sum): 0.05873, Running average loss:0.29092, Time taken: 69.9285786151886 ETA: 41.873400368376394
# 2025-08-05 11:39:36,552 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.401198/5:, Cur-Step: 1470, loss(cross_dice_sum): 0.05873, Running average loss:0.29092, Time taken: 69.9285786151886 ETA: 41.873400368376394
# Epoch: 4.431138/5:, Cur-Step: 1480, loss(cross_dice_sum): 0.06320, Running average loss:0.28447, Time taken: 69.9285786151886 ETA: 39.779730349957596
# 2025-08-05 11:39:38,741 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.431138/5:, Cur-Step: 1480, loss(cross_dice_sum): 0.06320, Running average loss:0.28447, Time taken: 69.9285786151886 ETA: 39.779730349957596
# Epoch: 4.461078/5:, Cur-Step: 1490, loss(cross_dice_sum): 0.07512, Running average loss:0.28010, Time taken: 69.9285786151886 ETA: 37.686060331538734
# 2025-08-05 11:39:40,824 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.461078/5:, Cur-Step: 1490, loss(cross_dice_sum): 0.07512, Running average loss:0.28010, Time taken: 69.9285786151886 ETA: 37.686060331538734
# Epoch: 4.491018/5:, Cur-Step: 1500, loss(cross_dice_sum): 0.11111, Running average loss:0.27492, Time taken: 69.9285786151886 ETA: 35.592390313119935
# 2025-08-05 11:39:42,878 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.491018/5:, Cur-Step: 1500, loss(cross_dice_sum): 0.11111, Running average loss:0.27492, Time taken: 69.9285786151886 ETA: 35.592390313119935
# Epoch: 4.520958/5:, Cur-Step: 1510, loss(cross_dice_sum): 0.15474, Running average loss:0.27329, Time taken: 69.9285786151886 ETA: 33.498720294701144
# 2025-08-05 11:39:44,947 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.520958/5:, Cur-Step: 1510, loss(cross_dice_sum): 0.15474, Running average loss:0.27329, Time taken: 69.9285786151886 ETA: 33.498720294701144
# Epoch: 4.550898/5:, Cur-Step: 1520, loss(cross_dice_sum): 0.39200, Running average loss:0.27067, Time taken: 69.9285786151886 ETA: 31.40505027628228
# 2025-08-05 11:39:47,029 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.550898/5:, Cur-Step: 1520, loss(cross_dice_sum): 0.39200, Running average loss:0.27067, Time taken: 69.9285786151886 ETA: 31.40505027628228
# Epoch: 4.580838/5:, Cur-Step: 1530, loss(cross_dice_sum): 0.73512, Running average loss:0.27378, Time taken: 69.9285786151886 ETA: 29.311380257863483
# 2025-08-05 11:39:49,143 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.580838/5:, Cur-Step: 1530, loss(cross_dice_sum): 0.73512, Running average loss:0.27378, Time taken: 69.9285786151886 ETA: 29.311380257863483
# Epoch: 4.610778/5:, Cur-Step: 1540, loss(cross_dice_sum): 0.77026, Running average loss:0.27643, Time taken: 69.9285786151886 ETA: 27.217710239444685
# 2025-08-05 11:39:51,235 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.610778/5:, Cur-Step: 1540, loss(cross_dice_sum): 0.77026, Running average loss:0.27643, Time taken: 69.9285786151886 ETA: 27.217710239444685
# Epoch: 4.640719/5:, Cur-Step: 1550, loss(cross_dice_sum): 0.10589, Running average loss:0.28287, Time taken: 69.9285786151886 ETA: 25.124040221025826
# 2025-08-05 11:39:53,326 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.640719/5:, Cur-Step: 1550, loss(cross_dice_sum): 0.10589, Running average loss:0.28287, Time taken: 69.9285786151886 ETA: 25.124040221025826
# Epoch: 4.670659/5:, Cur-Step: 1560, loss(cross_dice_sum): 0.57359, Running average loss:0.28764, Time taken: 69.9285786151886 ETA: 23.030370202607028
# 2025-08-05 11:39:55,417 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.670659/5:, Cur-Step: 1560, loss(cross_dice_sum): 0.57359, Running average loss:0.28764, Time taken: 69.9285786151886 ETA: 23.030370202607028
# Epoch: 4.700599/5:, Cur-Step: 1570, loss(cross_dice_sum): 0.41954, Running average loss:0.29117, Time taken: 69.9285786151886 ETA: 20.93670018418823
# 2025-08-05 11:39:57,477 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.700599/5:, Cur-Step: 1570, loss(cross_dice_sum): 0.41954, Running average loss:0.29117, Time taken: 69.9285786151886 ETA: 20.93670018418823
# Epoch: 4.730539/5:, Cur-Step: 1580, loss(cross_dice_sum): 0.27545, Running average loss:0.28521, Time taken: 69.9285786151886 ETA: 18.843030165769367
# 2025-08-05 11:39:59,568 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.730539/5:, Cur-Step: 1580, loss(cross_dice_sum): 0.27545, Running average loss:0.28521, Time taken: 69.9285786151886 ETA: 18.843030165769367
# Epoch: 4.760479/5:, Cur-Step: 1590, loss(cross_dice_sum): 0.62893, Running average loss:0.28292, Time taken: 69.9285786151886 ETA: 16.749360147350572
# 2025-08-05 11:40:01,636 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.760479/5:, Cur-Step: 1590, loss(cross_dice_sum): 0.62893, Running average loss:0.28292, Time taken: 69.9285786151886 ETA: 16.749360147350572
# Epoch: 4.790419/5:, Cur-Step: 1600, loss(cross_dice_sum): 0.11712, Running average loss:0.27921, Time taken: 69.9285786151886 ETA: 14.655690128931772
# 2025-08-05 11:40:03,706 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.790419/5:, Cur-Step: 1600, loss(cross_dice_sum): 0.11712, Running average loss:0.27921, Time taken: 69.9285786151886 ETA: 14.655690128931772
# Epoch: 4.820359/5:, Cur-Step: 1610, loss(cross_dice_sum): 0.06206, Running average loss:0.28129, Time taken: 69.9285786151886 ETA: 12.562020110512913
# 2025-08-05 11:40:05,789 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.820359/5:, Cur-Step: 1610, loss(cross_dice_sum): 0.06206, Running average loss:0.28129, Time taken: 69.9285786151886 ETA: 12.562020110512913
# Epoch: 4.850299/5:, Cur-Step: 1620, loss(cross_dice_sum): 0.34047, Running average loss:0.28137, Time taken: 69.9285786151886 ETA: 10.468350092094115
# 2025-08-05 11:40:07,863 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.850299/5:, Cur-Step: 1620, loss(cross_dice_sum): 0.34047, Running average loss:0.28137, Time taken: 69.9285786151886 ETA: 10.468350092094115
# Epoch: 4.880240/5:, Cur-Step: 1630, loss(cross_dice_sum): 0.10789, Running average loss:0.27863, Time taken: 69.9285786151886 ETA: 8.374680073675254
# 2025-08-05 11:40:09,937 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.880240/5:, Cur-Step: 1630, loss(cross_dice_sum): 0.10789, Running average loss:0.27863, Time taken: 69.9285786151886 ETA: 8.374680073675254
# Epoch: 4.910180/5:, Cur-Step: 1640, loss(cross_dice_sum): 0.19489, Running average loss:0.27601, Time taken: 69.9285786151886 ETA: 6.2810100552564565
# 2025-08-05 11:40:12,102 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.910180/5:, Cur-Step: 1640, loss(cross_dice_sum): 0.19489, Running average loss:0.27601, Time taken: 69.9285786151886 ETA: 6.2810100552564565
# Epoch: 4.940120/5:, Cur-Step: 1650, loss(cross_dice_sum): 0.19246, Running average loss:0.27592, Time taken: 69.9285786151886 ETA: 4.187340036837658
# 2025-08-05 11:40:14,168 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.940120/5:, Cur-Step: 1650, loss(cross_dice_sum): 0.19246, Running average loss:0.27592, Time taken: 69.9285786151886 ETA: 4.187340036837658
# Epoch: 4.970060/5:, Cur-Step: 1660, loss(cross_dice_sum): 0.12554, Running average loss:0.27328, Time taken: 69.9285786151886 ETA: 2.093670018418798
# 2025-08-05 11:40:16,252 [TAO Toolkit] [INFO] __main__ 161: Epoch: 4.970060/5:, Cur-Step: 1660, loss(cross_dice_sum): 0.12554, Running average loss:0.27328, Time taken: 69.9285786151886 ETA: 2.093670018418798
# Throughput Avg: 4.805 img/s
# Latency Avg: 211.368 ms
# Latency 90%: 215.864 ms
# Latency 95%: 216.725 ms
# Latency 99%: 218.409 ms
# DLL 2025-08-05 11:40:18.286657 - () throughput_train:4.805460829742901  latency_train:211.36758268915156 elapsed_time:369.744583
# INFO:tensorflow:Saving checkpoints for step-1670.
# 2025-08-05 11:40:18,287 [TAO Toolkit] [INFO] tensorflow 76: Saving checkpoints for step-1670.
# INFO:tensorflow:Loss for final step: 0.3242788.
# 2025-08-05 11:40:18,881 [TAO Toolkit] [INFO] tensorflow 371: Loss for final step: 0.3242788.
# Saving the final step model to /workspace/tao-experiments/unet/resnet18/weights/resnet18.tlt
# 2025-08-05 11:40:18,882 [TAO Toolkit] [INFO] __main__ 302: Saving the final step model to /workspace/tao-experiments/unet/resnet18/weights/resnet18.tlt
# 2025-08-05 11:40:19,086 [TAO Toolkit] [INFO] root 2102: Unet training complete.
# 2025-08-05 11:40:19,087 [TAO Toolkit] [INFO] root 2102: Experiment complete.
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error Url for the certificates not found.>
# Execution status: PASS
# 2025-08-05 11:40:41,140 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 363: Stopping container.

# %% [markdown]
# **Note**: The training may take hours to complete. `unet` supports restarting from checkpoints in case the training job is killed prematurely. Training from the closest checkpoint may be resumed by simply re-running the **same** command.

# %%
# DO NOT CHANGE THIS CELL
print('Model for every epoch at checkpoint_interval mentioned in the spec file:')
print('---------------------')
# !tree -a $LOCAL_EXPERIMENT_DIR/resnet18
# Out:
# Model for every epoch at checkpoint_interval mentioned in the spec file:
# ---------------------
# /dli/task/tao_project/unet/resnet18
# ├── events
# ├── events.out.tfevents.1754393652.56946365f9fe
# ├── experiment_spec.txt
# ├── graph.pbtxt
# ├── log.txt
# ├── model.epoch-0.tlt
# │   ├── checkpoint
# │   ├── model.ckpt-0.data-00000-of-00002
# │   ├── model.ckpt-0.data-00001-of-00002
# │   ├── model.ckpt-0.index
# │   └── model.ckpt-0.meta
# ├── model.epoch-5.tlt
# │   ├── checkpoint
# │   ├── model.ckpt-5.data-00000-of-00002
# │   ├── model.ckpt-5.data-00001-of-00002
# │   ├── model.ckpt-5.index
# │   └── model.ckpt-5.meta
# ├── monitor.json
# ├── output.log
# ├── profile_log.txt
# ├── results_tlt.json
# ├── status.json
# ├── target_class_id_mapping.json
# └── weights
#     ├── labels.txt
#     ├── nvinfer_config.txt
#     ├── resnet18.onnx
#     ├── resnet18.tlt
#     │   ├── checkpoint
#     │   ├── model.ckpt-5.data-00000-of-00002
#     │   ├── model.ckpt-5.data-00001-of-00002
#     │   ├── model.ckpt-5.index
#     │   └── model.ckpt-5.meta
#     └── status.json
#
# 5 directories, 29 files

# %% [markdown]
# <a name='s2-2.7'></a>
# ### Evaluating the Model ###
# The model should be evaluated for its performance at the end of training. The last step model saved in the `$USER_EXPERIMENT_DIR/resnet18/weights` directory is used for evaluation, inference, and export. The evaluation metrics include **precision**, **recall**, **f1-score**, and **IOU** for every class. The evaluation also creates `results_tlt.json` as a record. We can evaluate the model with the `evaluate` subtask.

# %% [raw]
# tao model unet evaluate [-h] -e <EXPERIMENT_SPEC_FILE>
#                              -m <MODEL_PATH>
#                              -o <OUTPUT_DIR>
#                              -k <KEY>
#                              [--gpus GPUS]
#                              [--gpu_index GPU_INDEX]

# %% [markdown]
# The `evaluate` subtask runs evaluation on the same validation set that was used during training. We can also run evaluation on an earlier model by editing the spec file to point to the intended model. When using the `evaluate` subtask, the `-e` argument indicates the path to the spec file, the `-m` argument indicates the path to the model, the `-o` argument indicates where the evaluation metrics outputs should be written, and the `-k` argument indicates the key to _load_ the model.

# %%
# DO NOT CHANGE THIS CELL
# evaluate the model using the same validation set as training
# !tao model unet evaluate -e $TAO_SPECS_DIR/resnet18/combined_config.txt\
                         -m $TAO_EXPERIMENT_DIR/resnet18/weights/resnet18.tlt \
                         -o $TAO_EXPERIMENT_DIR/resnet18/ \
                         -k $KEY
# Out:
# 2025-08-05 11:40:41,818 [TAO Toolkit] [INFO] root 160: Registry: ['nvcr.io']
# 2025-08-05 11:40:41,922 [TAO Toolkit] [INFO] nvidia_tao_cli.components.instance_handler.local_instance 360: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:5.0.0-tf1.15.5
# 2025-08-05 11:40:41,936 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 301: Printing tty value True
# 2025-08-05 11:40:42.635680: I tensorflow/stream_executor/platform/default/dso_loader.cc:50] Successfully opened dynamic library libcudart.so.12
# 2025-08-05 11:40:42,689 [TAO Toolkit] [WARNING] tensorflow 40: Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# 2025-08-05 11:40:44,475 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:40:44,510 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:40:44,514 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:40:44,798 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2025-08-05 11:40:44,798 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.WARN is deprecated. Please use tf.compat.v1.logging.WARN instead.
#
# 2025-08-05 11:40:45,177 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:40:45,834 [TAO Toolkit] [INFO] matplotlib.font_manager 1633: generated new fontManager
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# WARNING:tensorflow:TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/evaluate.py:57: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/evaluate.py:57: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/evaluate.py:57: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/evaluate.py:57: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# INFO: Log file already exists at /workspace/tao-experiments/unet/resnet18/status.json
# INFO: Starting UNet Evaluation
# INFO: Loading experiment spec at /workspace/tao-experiments/spec_files/resnet18/combined_config.txt.
# INFO: Merging specification from /workspace/tao-experiments/spec_files/resnet18/combined_config.txt
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# INFO: Label Id 0: Train Id 0
# INFO: Label Id 255: Train Id 1
#
# Phase val: Total 112 files.
# model.ckpt-5.meta
# INFO:tensorflow:Using config: {'_model_dir': '/workspace/tao-experiments/unet/resnet18/weights', '_tf_random_seed': None, '_save_summary_steps': 1, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f646dda51f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO: Using config: {'_model_dir': '/workspace/tao-experiments/unet/resnet18/weights', '_tf_random_seed': None, '_save_summary_steps': 1, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f646dda51f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO: Starting Evaluation.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# /usr/local/lib/python3.8/dist-packages/third_party/keras/tensorflow_backend.py:367: UserWarning: Creating resources inside a function passed to Dataset.map() is not supported. Create each resource outside the function, and capture it inside the function to use it.
#   return old_map(
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_pad is deprecated. Please use tf.compat.v1.image.resize_image_with_pad instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_pad is deprecated. Please use tf.compat.v1.image.resize_image_with_pad instead.
#
# INFO:tensorflow:Calling model_fn.
# INFO: Calling model_fn.
# INFO: {'exec_mode': 'train', 'model_dir': '/workspace/tao-experiments/unet/resnet18/weights', 'resize_padding': False, 'resize_method': 'BILINEAR', 'log_dir': None, 'batch_size': 1, 'learning_rate': 9.999999747378752e-05, 'activation': 'softmax', 'crossvalidation_idx': None, 'max_steps': None, 'regularizer_type': 2, 'weight_decay': 1.9999999494757503e-05, 'log_summary_steps': 10, 'warmup_steps': 0, 'augment': True, 'use_amp': False, 'filter_data': False, 'use_trt': False, 'use_xla': False, 'loss': 'cross_dice_sum', 'epochs': 5, 'pretrained_weights_file': None, 'lr_scheduler': None, 'unet_model': <nvidia_tao_tf1.cv.unet.model.resnet_unet.ResnetUnet object at 0x7f646d583df0>, 'key': 'my_model_key', 'experiment_spec': dataset_config {
#   augment: true
#   dataset: "custom"
#   input_image_type: "color"
#   train_images_path: "/workspace/tao-experiments/data/images/train"
#   train_masks_path: "/workspace/tao-experiments/data/masks/train"
#   val_images_path: "/workspace/tao-experiments/data/images/val"
#   val_masks_path: "/workspace/tao-experiments/data/masks/val"
#   test_images_path: "/workspace/tao-experiments/data/images/val"
#   data_class_config {
#     target_classes {
#       name: "notflood"
#       mapping_class: "notflood"
#     }
#     target_classes {
#       name: "flood"
#       label_id: 255
#       mapping_class: "flood"
#     }
#   }
#   augmentation_config {
#     spatial_augmentation {
#       hflip_probability: 0.5
#       vflip_probability: 0.5
#       crop_and_resize_prob: 0.5
#     }
#   }
# }
# model_config {
#   num_layers: 18
#   training_precision {
#     backend_floatx: FLOAT32
#   }
#   arch: "resnet"
#   all_projections: true
#   model_input_height: 512
#   model_input_width: 512
#   model_input_channels: 3
# }
# training_config {
#   batch_size: 1
#   regularizer {
#     type: L2
#     weight: 1.9999999494757503e-05
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993922529e-09
#       beta1: 0.8999999761581421
#       beta2: 0.9990000128746033
#     }
#   }
#   checkpoint_interval: 10
#   log_summary_steps: 10
#   learning_rate: 9.999999747378752e-05
#   loss: "cross_dice_sum"
#   epochs: 5
# }
# , 'seed': 0, 'benchmark': False, 'temp_dir': '/tmp/tmpm35pmcem', 'num_classes': 2, 'num_conf_mat_classes': 2, 'start_step': 0, 'checkpoint_interval': 10, 'model_json': None, 'custom_objs': {}, 'load_graph': False, 'remove_head': False, 'buffer_size': None, 'data_options': False, 'weights_monitor': False, 'visualize': False, 'save_summary_steps': None, 'infrequent_save_summary_steps': None, 'enable_qat': False, 'phase': 'val', 'model_size': 0.00390625}
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 512, 512)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 256, 256) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 256, 256) 0           conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        activation_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 128, 128) 0           block_1a_conv_2[0][0]
#                                                                  block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 128, 128) 0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 128, 128) 0           block_1b_conv_2[0][0]
#                                                                  block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 128, 128) 0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 64, 64)  73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 64, 64)  8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 64, 64)  0           block_2a_conv_2[0][0]
#                                                                  block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 64, 64)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (None, 128, 64, 64)  16512       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 64, 64)  0           block_2b_conv_2[0][0]
#                                                                  block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 64, 64)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 32, 32)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 32, 32)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 32, 32)  0           block_3a_conv_2[0][0]
#                                                                  block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 32, 32)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (None, 256, 32, 32)  65792       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 32, 32)  0           block_3b_conv_2[0][0]
#                                                                  block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 32, 32)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 32, 32)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 32, 32)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 32, 32)  0           block_4a_conv_2[0][0]
#                                                                  block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 32, 32)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (None, 512, 32, 32)  262656      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 32, 32)  0           block_4b_conv_2[0][0]
#                                                                  block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 32, 32)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 64, 64)  2097408     block_4b_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384, 64, 64)  0           conv2d_transpose_1[0][0]
#                                                                  block_2b_relu[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 384, 64, 64)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 64, 64)  884992      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 64, 64)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 524416      activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 192, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  block_1b_relu[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 192, 128, 128 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 221312      activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 256, 256) 131136      activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 256, 256 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 256, 256 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 256, 256) 73792       activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 256, 256) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 512, 512) 65600       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 512, 512) 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 512, 512) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 512, 512) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 512, 512)  1154        activation_9[0][0]
# ==================================================================================================
# Total params: 15,561,730
# Trainable params: 15,561,730
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Done calling model_fn.
# INFO: Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO: Graph was finalized.
# INFO:tensorflow:Restoring parameters from /workspace/tao-experiments/unet/resnet18/weights/resnet18.tlt/model.ckpt-5
# INFO: Restoring parameters from /workspace/tao-experiments/unet/resnet18/weights/resnet18.tlt/model.ckpt-5
# INFO:tensorflow:Running local_init_op.
# INFO: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO: Done running local_init_op.
# 112it [00:12,  9.04it/s]
# INFO: None
# Recall : 0.7325378358364105
#
# Precision: 0.888251394033432
#
# F1 score: 0.7865812342427362
#
# Mean IOU: 0.6869432330131531
#
# INFO: Evaluation finished successfully.
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error Url for the certificates not found.>
# Execution status: PASS
# 2025-08-05 11:41:21,802 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 363: Stopping container.

# %% [markdown]
# To understand how the TAO Toolkit measures accuracy of the segmentation model, we'll have to understand two measures: **recall** and **precision**. The first measure is focused on identifying positive cases and is called recall. We define recall as the ability of the model to identify all true positive samples of the dataset. In mathematical terms, recall is the ratio of true positives over true positives plus false negatives. By other means, recall tells us, among all the test samples belonging to the output class, how many of them are identified correctly by the model. The next measure is called precision and is defined as the ability of the model to identify the relevant samples only. It is the ratio of true positives over true positives plus false positives. A well-known measure that summarizes the balance between precision and recall is **f1-score**, which is their harmonic mean.

# %% [markdown]
# <a name='s2-2.8'></a>
# ### Visualizing Model Inference ###
# The `inference` subtask for `unet` may be used to visualize segmentation and generate frame-by-frame PNG format labels on a directory of images. The labels will be generated in `mask_labels_tlt`. The tool also automatically generates segmentation overlayed images in `vis_overlay_tlt`.

# %% [raw]
# tao model unet inference [-h] -e <EXPERIMENT_SPEC_FILE>
#                               -m <MODEL_PATH>
#                               -o <OUTPUT_DIR>
#                               -k <KEY>
#                               [--gpus GPUS]
#                               [--gpu_index GPU_INDEX]

# %% [markdown]
# When using the `inference` subtask, the `-e` argument indicates the path to the inference spec file, the `-m` argument indicates the path to the model file, the `-o` argument indicates the path to the output images directory, and the `-k` argument indicates the key to _load_ the model.

# %%
# DO NOT CHANGE THIS CELL
# remove any previous inference
# !rm -rf $LOCAL_PROJECT_DIR/tao_infer_testing/*

# %%
# DO NOT CHANGE THIS CELL
# perform inference on the validation set
# !tao model unet inference -e $TAO_SPECS_DIR/resnet18/combined_config.txt \
                          -m $TAO_EXPERIMENT_DIR/resnet18/weights/resnet18.tlt \
                          -o $TAO_PROJECT_DIR/tao_infer_testing \
                          -k $KEY
# Out:
# 2025-08-05 11:41:22,474 [TAO Toolkit] [INFO] root 160: Registry: ['nvcr.io']
# 2025-08-05 11:41:22,574 [TAO Toolkit] [INFO] nvidia_tao_cli.components.instance_handler.local_instance 360: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:5.0.0-tf1.15.5
# 2025-08-05 11:41:22,586 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 301: Printing tty value True
# 2025-08-05 11:41:23.259680: I tensorflow/stream_executor/platform/default/dso_loader.cc:50] Successfully opened dynamic library libcudart.so.12
# 2025-08-05 11:41:23,314 [TAO Toolkit] [WARNING] tensorflow 40: Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# 2025-08-05 11:41:25,096 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:41:25,131 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:41:25,135 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:41:25,425 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2025-08-05 11:41:25,425 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.WARN is deprecated. Please use tf.compat.v1.logging.WARN instead.
#
# 2025-08-05 11:41:25,804 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:41:26,471 [TAO Toolkit] [INFO] matplotlib.font_manager 1633: generated new fontManager
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# WARNING:tensorflow:TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:41:27,960 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:41:27,992 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:41:27,995 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2025-08-05 11:41:28,605 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:41:28,605 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:41:28,606 [TAO Toolkit] [INFO] root 2102: Starting UNet Inference
# 2025-08-05 11:41:28,606 [TAO Toolkit] [INFO] __main__ 365: Loading experiment spec at /workspace/tao-experiments/spec_files/resnet18/combined_config.txt.
# 2025-08-05 11:41:28,607 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.spec_handler.spec_loader 59: Merging specification from /workspace/tao-experiments/spec_files/resnet18/combined_config.txt
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-08-05 11:41:28,608 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2025-08-05 11:41:28,608 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 0: Train Id 0
# 2025-08-05 11:41:28,608 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 255: Train Id 1
#
# Phase test: Total 112 files.
# model.ckpt-5.meta
# INFO:tensorflow:Using config: {'_model_dir': '/workspace/tao-experiments/unet/resnet18/weights', '_tf_random_seed': None, '_save_summary_steps': 1, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   allow_growth: true
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffb00f25220>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 2025-08-05 11:41:28,626 [TAO Toolkit] [INFO] tensorflow 212: Using config: {'_model_dir': '/workspace/tao-experiments/unet/resnet18/weights', '_tf_random_seed': None, '_save_summary_steps': 1, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   allow_growth: true
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffb00f25220>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# 0it [00:00, ?it/s]WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2025-08-05 11:41:28,649 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# 2025-08-05 11:41:29,024 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# 2025-08-05 11:41:29,025 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_pad is deprecated. Please use tf.compat.v1.image.resize_image_with_pad instead.
#
# 2025-08-05 11:41:29,025 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.image.resize_image_with_pad is deprecated. Please use tf.compat.v1.image.resize_image_with_pad instead.
#
# INFO:tensorflow:Calling model_fn.
# 2025-08-05 11:41:29,674 [TAO Toolkit] [INFO] tensorflow 1148: Calling model_fn.
# 2025-08-05 11:41:29,674 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.utils.model_fn 196: {'exec_mode': 'train', 'model_dir': '/workspace/tao-experiments/unet/resnet18/weights', 'resize_padding': False, 'resize_method': 'BILINEAR', 'log_dir': None, 'batch_size': 1, 'learning_rate': 9.999999747378752e-05, 'activation': 'softmax', 'crossvalidation_idx': None, 'max_steps': None, 'regularizer_type': 2, 'weight_decay': 1.9999999494757503e-05, 'log_summary_steps': 10, 'warmup_steps': 0, 'augment': True, 'use_amp': False, 'filter_data': False, 'use_trt': False, 'use_xla': False, 'loss': 'cross_dice_sum', 'epochs': 5, 'pretrained_weights_file': None, 'lr_scheduler': None, 'unet_model': <nvidia_tao_tf1.cv.unet.model.resnet_unet.ResnetUnet object at 0x7ffb0068d940>, 'key': 'my_model_key', 'experiment_spec': dataset_config {
#   augment: true
#   dataset: "custom"
#   input_image_type: "color"
#   train_images_path: "/workspace/tao-experiments/data/images/train"
#   train_masks_path: "/workspace/tao-experiments/data/masks/train"
#   val_images_path: "/workspace/tao-experiments/data/images/val"
#   val_masks_path: "/workspace/tao-experiments/data/masks/val"
#   test_images_path: "/workspace/tao-experiments/data/images/val"
#   data_class_config {
#     target_classes {
#       name: "notflood"
#       mapping_class: "notflood"
#     }
#     target_classes {
#       name: "flood"
#       label_id: 255
#       mapping_class: "flood"
#     }
#   }
#   augmentation_config {
#     spatial_augmentation {
#       hflip_probability: 0.5
#       vflip_probability: 0.5
#       crop_and_resize_prob: 0.5
#     }
#   }
# }
# model_config {
#   num_layers: 18
#   training_precision {
#     backend_floatx: FLOAT32
#   }
#   arch: "resnet"
#   all_projections: true
#   model_input_height: 512
#   model_input_width: 512
#   model_input_channels: 3
# }
# training_config {
#   batch_size: 1
#   regularizer {
#     type: L2
#     weight: 1.9999999494757503e-05
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993922529e-09
#       beta1: 0.8999999761581421
#       beta2: 0.9990000128746033
#     }
#   }
#   checkpoint_interval: 10
#   log_summary_steps: 10
#   learning_rate: 9.999999747378752e-05
#   loss: "cross_dice_sum"
#   epochs: 5
# }
# , 'seed': 0, 'benchmark': False, 'temp_dir': '/tmp/tmpqh26gsww', 'num_classes': 2, 'num_conf_mat_classes': 2, 'start_step': 0, 'checkpoint_interval': 10, 'model_json': None, 'custom_objs': {}, 'load_graph': False, 'remove_head': False, 'buffer_size': None, 'data_options': False, 'weights_monitor': False, 'visualize': False, 'save_summary_steps': None, 'infrequent_save_summary_steps': None, 'enable_qat': False, 'phase': 'test'}
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2025-08-05 11:41:29,675 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2025-08-05 11:41:29,675 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 512, 512)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 256, 256) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 256, 256) 0           conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        activation_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 128, 128) 0           block_1a_conv_2[0][0]
#                                                                  block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 128, 128) 0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 128, 128) 0           block_1b_conv_2[0][0]
#                                                                  block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 128, 128) 0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 64, 64)  73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 64, 64)  8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 64, 64)  0           block_2a_conv_2[0][0]
#                                                                  block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 64, 64)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (None, 128, 64, 64)  16512       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 64, 64)  0           block_2b_conv_2[0][0]
#                                                                  block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 64, 64)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 32, 32)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 32, 32)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 32, 32)  0           block_3a_conv_2[0][0]
#                                                                  block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 32, 32)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (None, 256, 32, 32)  65792       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 32, 32)  0           block_3b_conv_2[0][0]
#                                                                  block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 32, 32)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 32, 32)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 32, 32)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 32, 32)  0           block_4a_conv_2[0][0]
#                                                                  block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 32, 32)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (None, 512, 32, 32)  262656      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 32, 32)  0           block_4b_conv_2[0][0]
#                                                                  block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 32, 32)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 64, 64)  2097408     block_4b_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384, 64, 64)  0           conv2d_transpose_1[0][0]
#                                                                  block_2b_relu[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 384, 64, 64)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 64, 64)  884992      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 64, 64)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 524416      activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 192, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  block_1b_relu[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 192, 128, 128 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 221312      activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 256, 256) 131136      activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 256, 256 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 256, 256 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 256, 256) 73792       activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 256, 256) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 512, 512) 65600       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 512, 512) 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 512, 512) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 512, 512) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 512, 512)  1154        activation_9[0][0]
# ==================================================================================================
# Total params: 15,561,730
# Trainable params: 15,561,730
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Done calling model_fn.
# 2025-08-05 11:41:30,010 [TAO Toolkit] [INFO] tensorflow 1150: Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# 2025-08-05 11:41:30,113 [TAO Toolkit] [INFO] tensorflow 240: Graph was finalized.
# INFO:tensorflow:Restoring parameters from /workspace/tao-experiments/unet/resnet18/weights/resnet18.tlt/model.ckpt-5
# 2025-08-05 11:41:30,447 [TAO Toolkit] [INFO] tensorflow 1284: Restoring parameters from /workspace/tao-experiments/unet/resnet18/weights/resnet18.tlt/model.ckpt-5
# INFO:tensorflow:Running local_init_op.
# 2025-08-05 11:41:30,735 [TAO Toolkit] [INFO] tensorflow 500: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2025-08-05 11:41:30,751 [TAO Toolkit] [INFO] tensorflow 502: Done running local_init_op.
# 112it [00:14,  7.98it/s]
# 2025-08-05 11:41:42,668 [TAO Toolkit] [INFO] root 2102: Inference finished successfully.
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error Url for the certificates not found.>
# Execution status: PASS
# 2025-08-05 11:42:04,069 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 363: Stopping container.

# %% [markdown]
# We can write a quick function that will help us sample random inferences. Execute the below cells to visualize the inference.

# %%
# DO NOT CHANGE THIS CELL
# import dependencies
import matplotlib.pyplot as plt
import random

# define simple grid visualizer
def visualize_images(num_images=10):
    overlay_path=os.path.join(os.environ['LOCAL_PROJECT_DIR'], 'tao_infer_testing', 'vis_overlay_tlt')
    inference_path=os.path.join(os.environ['LOCAL_PROJECT_DIR'], 'tao_infer_testing', 'mask_labels_tlt')
    actual_path=os.path.join(os.environ['LOCAL_DATA_DIR'], 'masks', 'val')
    inference_images_path=os.path.join(os.environ['LOCAL_DATA_DIR'], 'images', 'val')
        
    fig_dim=4
    fig, ax_arr=plt.subplots(num_images, 4, figsize=[4*fig_dim, num_images*fig_dim], sharex=True, sharey=True)
    ax_arr[0, 0].set_title('Overlay')
    ax_arr[0, 1].set_title('Input')
    ax_arr[0, 2].set_title('Inference')
    ax_arr[0, 3].set_title('Actual')
    ax_arr[0, 0].set_xticks([])
    ax_arr[0, 0].set_yticks([])
    
    for idx, img_name in enumerate(random.sample(os.listdir(actual_path), num_images)):
        ax_arr[idx, 0].imshow(plt.imread(overlay_path+'/'+img_name))
        ax_arr[idx, 0].set_ylabel(img_name)
        ax_arr[idx, 1].imshow(plt.imread(inference_images_path+'/'+img_name))
        ax_arr[idx, 2].imshow(plt.imread(inference_path+'/'+img_name), cmap='gray')
        ax_arr[idx, 3].imshow(plt.imread(actual_path+'/'+img_name), cmap='gray')
    fig.tight_layout()

# %%
# DO NOT CHANGE THIS CELL
# visualizing random images
NUM_IMAGES = 4

visualize_images(NUM_IMAGES)

# %% [markdown]
# <a name='s2-3'></a>
# ## Model Export ##
# Once we are satisfied with our model, we can move to deployment. `unet` includes an `export` subtask to export and prepare a trained U-Net model for deployment. Exporting the model decouples the training process from deployment and allows conversion to TensorRT engines outside the TAO environment. TensorRT is a highly optimized package that takes trained models and optimizes them for inference. TensorRT engines are specific to each hardware configuration and should be generated for each unique inference environment. This may be interchangeably referred to as the `.trt` or `.engine` file. The same exported TAO model may be used universally across training and deployment hardware. This is referred to as the `.etlt` file, or encrypted TAO file.

# %% [markdown]
# <a name='s2-3.1'></a>
# ### TensorRT - Programmable Inference Accelerator
#
# NVIDIA [TensorRT](https://developer.nvidia.com/tensorrt) is a platform for high-performance deep learning inference. It includes a deep learning inference optimizer and runtime that delivers low latency and high throughput for deep learning inference applications. TensorRT-based applications perform up to 40x faster than CPU-only platforms during inference.
#
# With TensorRT, we can optimize neural network models trained in all major frameworks, calibrate for lower precision with high accuracy, and finally deploy to hyperscale data centers, embedded, or automotive product platforms.
#
# How TensorRT enables optimizations on the layer graph:
# * Elimination of layers whose outputs are not used
# * Fusion of convolution, bias, and ReLU operations
# * Aggregation of operations with sufficiently similar parameters and the same source tensor (for example, the 1x1 convolutions in GoogleNet’ s inception module)
# * Merging of concatenation layers by directing layer outputs to the correct eventual destination
#
# Here are some great resources to learn more about TensorRT:
#
# * Main Page: https://developer.nvidia.com/tensorrt
# * Blogs: https://devblogs.nvidia.com/speed-up-inference-tensorrt/
# * Download: https://developer.nvidia.com/nvidia-tensorrt-download
# * Documentation: https://docs.nvidia.com/deeplearning/sdk/tensorrt-developer-guide/index.html
# * Sample Code: https://docs.nvidia.com/deeplearning/sdk/tensorrt-sample-support-guide/index.html
# * GitHub: https://github.com/NVIDIA/TensorRT
# * NGC Container: https://ngc.nvidia.com/catalog/containers/nvidia:tensorrt

# %% [markdown]
# <a name='s2-3.2'></a>
# ### Export the Trained Model ###
# When using the `export` subtask, the `-m` argument indicates the path to the `.tlt` model file generated by `tao model unet train`, the `-e` argument indicates the path to the spec file, and `-k` argument indicates the key to _load_ the model. The `-o` argument specifies the path to save the exported model to, which is defaulted to `./<input_file>.onnx`. There is an optional argument, `--gen_ds_config`, that are useful for us. The `--gen_ds_config` argument indicates whether to generate a template inference configuration file as well as a label file.

# %% [raw]
# tao model unet export [-h] -e <EXPERIMENT_SPEC>
#                            -m <MODEL>
#                            -k <KEY>
#                            [-o OUTPUT_PATH]
#                            [--engine_file ENGINE_FILE]
#                            [--gen_ds_config]
#                            [--gpus GPUS]
#                            [--gpu_index GPU_INDEX]

# %%
# DO NOT CHANGE THIS CELL
# remove any previous exports if exists
# !rm $LOCAL_EXPERIMENT_DIR/resnet18/weights/resnet18.onnx
# Out:
# rm: cannot remove '/dli/task/tao_project/unet/resnet18/weights/resnet18.onnx': No such file or directory

# %%
# DO NOT CHANGE THIS CELL
# export model
# !tao model unet export -m $TAO_EXPERIMENT_DIR/resnet18/weights/resnet18.tlt \
                       -e $TAO_SPECS_DIR/resnet18/combined_config.txt \
                       -k $KEY \
                       --gen_ds_config
# Out:
# 2025-08-05 11:42:06,992 [TAO Toolkit] [INFO] root 160: Registry: ['nvcr.io']
# 2025-08-05 11:42:07,090 [TAO Toolkit] [INFO] nvidia_tao_cli.components.instance_handler.local_instance 360: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:5.0.0-tf1.15.5
# 2025-08-05 11:42:07,103 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 301: Printing tty value True
# 2025-08-05 11:42:07.789743: I tensorflow/stream_executor/platform/default/dso_loader.cc:50] Successfully opened dynamic library libcudart.so.12
# 2025-08-05 11:42:07,844 [TAO Toolkit] [WARNING] tensorflow 40: Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# 2025-08-05 11:42:09,610 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:42:09,644 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:42:09,648 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:42:09,941 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2025-08-05 11:42:09,941 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/hooks/pretrained_restore_hook.py:35: The name tf.logging.WARN is deprecated. Please use tf.compat.v1.logging.WARN instead.
#
# 2025-08-05 11:42:10,327 [TAO Toolkit] [WARNING] tensorflow 137: From /usr/local/lib/python3.8/dist-packages/nvidia_tao_tf1/cv/unet/scripts/inference.py:58: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# 2025-08-05 11:42:10,988 [TAO Toolkit] [INFO] matplotlib.font_manager 1633: generated new fontManager
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# Using TensorFlow backend.
# WARNING:tensorflow:TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:42:12,515 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use sklearn by default. This improves performance in some cases. To enable sklearn export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:42:12,547 [TAO Toolkit] [WARNING] tensorflow 42: TensorFlow will not use Dask by default. This improves performance in some cases. To enable Dask export the environment variable  TF_ALLOW_IOLIBS=1.
# WARNING:tensorflow:TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:42:12,550 [TAO Toolkit] [WARNING] tensorflow 43: TensorFlow will not use Pandas by default. This improves performance in some cases. To enable Pandas export the environment variable  TF_ALLOW_IOLIBS=1.
# 2025-08-05 11:42:13,494 [TAO Toolkit] [INFO] root 2102: Building exporter object.
# 2025-08-05 11:42:13,494 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.common.export.keras_exporter 119: Setting the onnx export route to keras2onnx
# 2025-08-05 11:42:13,495 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.spec_handler.spec_loader 59: Merging specification from /workspace/tao-experiments/spec_files/resnet18/combined_config.txt
# 2025-08-05 11:42:13,497 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 0: Train Id 0
# 2025-08-05 11:42:13,497 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 255: Train Id 1
# model.ckpt-5.meta
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 512, 512)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 256, 256) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 256, 256) 0           conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        activation_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 128, 128) 0           block_1a_conv_2[0][0]
#                                                                  block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 128, 128) 0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 128, 128) 36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 128, 128) 0           block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 128, 128) 36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_shortcut (Conv2D) (None, 64, 128, 128) 4160        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 128, 128) 0           block_1b_conv_2[0][0]
#                                                                  block_1b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 128, 128) 0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 64, 64)  73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 64, 64)  8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 64, 64)  0           block_2a_conv_2[0][0]
#                                                                  block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 64, 64)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 64, 64)  147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 64, 64)  0           block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 64, 64)  147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_shortcut (Conv2D) (None, 128, 64, 64)  16512       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 64, 64)  0           block_2b_conv_2[0][0]
#                                                                  block_2b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 64, 64)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 32, 32)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 32, 32)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 32, 32)  0           block_3a_conv_2[0][0]
#                                                                  block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 32, 32)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 32, 32)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 32, 32)  0           block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 32, 32)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_shortcut (Conv2D) (None, 256, 32, 32)  65792       block_3a_relu[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 32, 32)  0           block_3b_conv_2[0][0]
#                                                                  block_3b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 32, 32)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 32, 32)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 32, 32)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 32, 32)  0           block_4a_conv_2[0][0]
#                                                                  block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 32, 32)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 32, 32)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 32, 32)  0           block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 32, 32)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_shortcut (Conv2D) (None, 512, 32, 32)  262656      block_4a_relu[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 32, 32)  0           block_4b_conv_2[0][0]
#                                                                  block_4b_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 32, 32)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 256, 64, 64)  2097408     block_4b_relu[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 384, 64, 64)  0           conv2d_transpose_1[0][0]
#                                                                  block_2b_relu[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 384, 64, 64)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 64, 64)  884992      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 64, 64)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 524416      activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 192, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  block_1b_relu[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 192, 128, 128 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 221312      activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 256, 256) 131136      activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 256, 256 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 256, 256 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 256, 256) 73792       activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 256, 256) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 512, 512) 65600       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 512, 512) 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 512, 512) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 512, 512) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 2, 512, 512)  1154        activation_9[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 512, 512, 2)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, 512, 512, 2)  0           permute_1[0][0]
# ==================================================================================================
# Total params: 15,561,730
# Trainable params: 15,561,730
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2025-08-05 11:42:14,628 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.model_io 103: Loaded weights Successfully for Export
# 2025-08-05 11:42:14,629 [TAO Toolkit] [INFO] root 2102: Exporting the model.
# 2025-08-05 11:42:14,629 [TAO Toolkit] [INFO] root 2102: Using input nodes: ['input_1']
# 2025-08-05 11:42:14,629 [TAO Toolkit] [INFO] root 2102: Using output nodes: ['softmax_1']
# 2025-08-05 11:42:14,629 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.common.export.keras_exporter 429: Using input nodes: ['input_1']
# 2025-08-05 11:42:14,629 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.common.export.keras_exporter 430: Using output nodes: ['softmax_1']
# Loaded model
# 2025-08-05 11:42:14,630 [TAO Toolkit] [WARNING] nvidia_tao_tf1.cv.unet.export.unet_exporter 220: UNet uses target opset of 11 by default.Overriding the provided opset None to 11.
# 2025-08-05 11:42:17,558 [TAO Toolkit] [WARNING] tf2onnx.tfonnx 409: Argument verbose for process_tf_graph is deprecated. Please use --verbose option instead.
# 2025-08-05 11:42:17,558 [TAO Toolkit] [INFO] tf2onnx.tfonnx 413: Using tensorflow=1.15.5, onnx=1.13.0, tf2onnx=1.9.2/0f28b7
# 2025-08-05 11:42:17,558 [TAO Toolkit] [INFO] tf2onnx.tfonnx 415: Using opset <onnx, 11>
# 2025-08-05 11:42:18,834 [TAO Toolkit] [INFO] tf2onnx.tf_utils 278: Computed 76 values for constant folding
# 2025-08-05 11:42:18,999 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv1/kernel/read
# 2025-08-05 11:42:19,000 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv1/bias/read
# 2025-08-05 11:42:19,000 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1a_conv_1/kernel/read
# 2025-08-05 11:42:19,000 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1a_conv_1/bias/read
# 2025-08-05 11:42:19,000 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1a_conv_2/kernel/read
# 2025-08-05 11:42:19,000 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1a_conv_2/bias/read
# 2025-08-05 11:42:19,000 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1a_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,000 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1a_conv_shortcut/bias/read
# 2025-08-05 11:42:19,001 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1b_conv_1/kernel/read
# 2025-08-05 11:42:19,001 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1b_conv_1/bias/read
# 2025-08-05 11:42:19,001 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1b_conv_2/kernel/read
# 2025-08-05 11:42:19,001 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1b_conv_2/bias/read
# 2025-08-05 11:42:19,001 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1b_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,001 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_1b_conv_shortcut/bias/read
# 2025-08-05 11:42:19,001 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2a_conv_1/kernel/read
# 2025-08-05 11:42:19,002 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2a_conv_1/bias/read
# 2025-08-05 11:42:19,002 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2a_conv_2/kernel/read
# 2025-08-05 11:42:19,002 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2a_conv_2/bias/read
# 2025-08-05 11:42:19,002 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2a_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,002 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2a_conv_shortcut/bias/read
# 2025-08-05 11:42:19,002 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2b_conv_1/kernel/read
# 2025-08-05 11:42:19,003 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2b_conv_1/bias/read
# 2025-08-05 11:42:19,003 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2b_conv_2/kernel/read
# 2025-08-05 11:42:19,003 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2b_conv_2/bias/read
# 2025-08-05 11:42:19,003 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2b_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,003 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_2b_conv_shortcut/bias/read
# 2025-08-05 11:42:19,003 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3a_conv_1/kernel/read
# 2025-08-05 11:42:19,004 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3a_conv_1/bias/read
# 2025-08-05 11:42:19,004 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3a_conv_2/kernel/read
# 2025-08-05 11:42:19,005 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3a_conv_2/bias/read
# 2025-08-05 11:42:19,005 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3a_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,005 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3a_conv_shortcut/bias/read
# 2025-08-05 11:42:19,005 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3b_conv_1/kernel/read
# 2025-08-05 11:42:19,006 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3b_conv_1/bias/read
# 2025-08-05 11:42:19,006 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3b_conv_2/kernel/read
# 2025-08-05 11:42:19,007 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3b_conv_2/bias/read
# 2025-08-05 11:42:19,007 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3b_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,007 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_3b_conv_shortcut/bias/read
# 2025-08-05 11:42:19,007 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4a_conv_1/kernel/read
# 2025-08-05 11:42:19,009 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4a_conv_1/bias/read
# 2025-08-05 11:42:19,009 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4a_conv_2/kernel/read
# 2025-08-05 11:42:19,014 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4a_conv_2/bias/read
# 2025-08-05 11:42:19,014 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4a_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,015 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4a_conv_shortcut/bias/read
# 2025-08-05 11:42:19,015 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4b_conv_1/kernel/read
# 2025-08-05 11:42:19,019 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4b_conv_1/bias/read
# 2025-08-05 11:42:19,019 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4b_conv_2/kernel/read
# 2025-08-05 11:42:19,024 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4b_conv_2/bias/read
# 2025-08-05 11:42:19,024 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4b_conv_shortcut/kernel/read
# 2025-08-05 11:42:19,024 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=block_4b_conv_shortcut/bias/read
# 2025-08-05 11:42:19,025 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_1/kernel/read
# 2025-08-05 11:42:19,027 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_1/bias/read
# 2025-08-05 11:42:19,028 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_1/mul
# 2025-08-05 11:42:19,028 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_1/mul_1
# 2025-08-05 11:42:19,028 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_1/kernel/read
# 2025-08-05 11:42:19,029 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_1/bias/read
# 2025-08-05 11:42:19,029 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_2/kernel/read
# 2025-08-05 11:42:19,030 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_2/bias/read
# 2025-08-05 11:42:19,030 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_2/mul
# 2025-08-05 11:42:19,030 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_2/mul_1
# 2025-08-05 11:42:19,030 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_2/kernel/read
# 2025-08-05 11:42:19,031 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_2/bias/read
# 2025-08-05 11:42:19,031 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_3/kernel/read
# 2025-08-05 11:42:19,031 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_3/bias/read
# 2025-08-05 11:42:19,031 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_3/mul
# 2025-08-05 11:42:19,031 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_3/mul_1
# 2025-08-05 11:42:19,031 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_3/kernel/read
# 2025-08-05 11:42:19,032 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_3/bias/read
# 2025-08-05 11:42:19,032 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_4/kernel/read
# 2025-08-05 11:42:19,032 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_transpose_4/bias/read
# 2025-08-05 11:42:19,032 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_4/mul
# 2025-08-05 11:42:19,032 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Mul, name=conv2d_transpose_4/mul_1
# 2025-08-05 11:42:19,032 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_4/kernel/read
# 2025-08-05 11:42:19,033 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_4/bias/read
# 2025-08-05 11:42:19,033 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_5/kernel/read
# 2025-08-05 11:42:19,033 [TAO Toolkit] [INFO] tf2onnx.tfonnx 45: folding node using tf type=Identity, name=conv2d_5/bias/read
# 2025-08-05 11:42:19,265 [TAO Toolkit] [INFO] tf2onnx.optimizer 48: Optimizing ONNX model
# 2025-08-05 11:42:19,811 [TAO Toolkit] [INFO] tf2onnx.optimizer 83: After optimization: Cast -4 (4->0), Concat -4 (7->3), Const -66 (134->68), Identity -1 (1->0), Reshape -26 (26->0), Shape -4 (4->0), Slice -4 (4->0), Squeeze -4 (4->0), Unsqueeze -16 (16->0)
# 2025-08-05 11:42:20,113 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.export.unet_exporter 202: New input/output
# 2025-08-05 11:42:20,114 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.export.unet_exporter 203: [name: "input_1:0"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_param: "unk__174"
#       }
#       dim {
#         dim_value: 3
#       }
#       dim {
#         dim_value: 512
#       }
#       dim {
#         dim_value: 512
#       }
#     }
#   }
# }
# ]
# 2025-08-05 11:42:20,114 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.export.unet_exporter 204: [name: "argmax_1"
# type {
#   tensor_type {
#     elem_type: 7
#     shape {
#       dim {
#         dim_param: "N"
#       }
#       dim {
#         dim_value: 512
#       }
#       dim {
#         dim_value: 512
#       }
#       dim {
#         dim_value: 1
#       }
#     }
#   }
# }
# ]
# 2025-08-05 11:42:20,245 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.export.unet_exporter 254: Converted model was saved into /workspace/tao-experiments/unet/resnet18/weights/resnet18.onnx
# 2025-08-05 11:42:20,254 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 0: Train Id 0
# 2025-08-05 11:42:20,254 [TAO Toolkit] [INFO] nvidia_tao_tf1.cv.unet.model.utilities 440: Label Id 255: Train Id 1
# 2025-08-05 11:42:20,255 [TAO Toolkit] [INFO] root 2102: Export complete.
# 2025-08-05 11:42:20,267 [TAO Toolkit] [INFO] root 2102: Unet export job complete.
# 2025-08-05 11:42:20,267 [TAO Toolkit] [INFO] root 2102: Export finished successfully.
# Telemetry data couldn't be sent, but the command ran successfully.
# [WARNING]: <urlopen error Url for the certificates not found.>
# Execution status: PASS
# 2025-08-05 11:42:41,880 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 363: Stopping container.

# %% [markdown]
# ### Generate TensorRT Engine
#
# The `.onnx` file generated from `tao model unet export` is taken as an input to `tao deploy unet` to generate an optimized TensorRT engine. When using the `gen_trt_engine` subtask, the `-m` argument indicates the path to the `.onnx` model file to be exported, the `-e` argument indicates the path to the spec file, the `-k` argument indicates the key to load the model, the `--engine_file` argument specifies the path to the serialized TensorRT engine file, and the `-r` argument indicates the directory where the JSON status-log file will be dumped. There is an optional argument, `--max_batch_size`, that is useful for us. The `----max_batch_size` argument indicates the maximum batch size of TensorRT engine, which is defaulted to `1`. The
#
#
# Note that the TensorRT file is hardware specific and cannot be generalized across GPUs. Since a TensorRT engine file is hardware specific, you cannot use an engine file for deployment unless the deployment GPU is identical to the training GPU. This is true in our case since the Triton Inference Server will run on the same hardware.

# %% [raw]
# tao deploy unet gen_trt_engine [-h] [-v] -m <MODEL_PATH>
#                                          -e <EXPERIMENT_SPEC>
#                                          -r <RESULTS_DIR>
#                                          [-k KEY]
#                                          [--max_batch_size MAX_BATCH_SIZE]
#                                          [--gpu_index GPU_INDEX]

# %%
# DO NOT CHANGE THIS CELL
# remove any previous engine if exists
# !rm $LOCAL_EXPERIMENT_DIR/export/resnet18.engine
# Out:
# rm: cannot remove '/dli/task/tao_project/unet/export/resnet18.engine': No such file or directory

# %%
# DO NOT CHANGE THIS CELL
# generate TensorRT engine
# !tao deploy unet gen_trt_engine -m $TAO_EXPERIMENT_DIR/resnet18/weights/resnet18.onnx \
                                -e $TAO_SPECS_DIR/resnet18/combined_config.txt \
                                -r $TAO_EXPERIMENT_DIR/export/ \
                                -k $KEY \
                                --engine_file $TAO_EXPERIMENT_DIR/export/resnet18.engine \
                                --max_batch_size 8
# Out:
# 2025-08-05 11:42:42,585 [TAO Toolkit] [INFO] root 160: Registry: ['nvcr.io']
# 2025-08-05 11:42:42,689 [TAO Toolkit] [INFO] nvidia_tao_cli.components.instance_handler.local_instance 360: Running command in container: nvcr.io/nvidia/tao/tao-toolkit:5.5.0-deploy
# 2025-08-05 11:42:42,704 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 301: Printing tty value True
# 2025-08-05 11:42:44,894 [TAO Toolkit] [INFO] root 167: Starting unet gen_trt_engine.
# [08/05/2025-11:42:44] [TRT] [I] [MemUsageChange] Init CUDA: CPU +2, GPU +0, now: CPU 35, GPU 533 (MiB)
# [08/05/2025-11:42:50] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +888, GPU +174, now: CPU 1000, GPU 707 (MiB)
# 2025-08-05 11:42:50,583 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 78: Parsing ONNX model
# 2025-08-05 11:42:50,616 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 63: List inputs:
# 2025-08-05 11:42:50,617 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 65: Input 0 -> input_1:0.
# 2025-08-05 11:42:50,617 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 66: [3, 512, 512].
# 2025-08-05 11:42:50,617 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 67: 0.
# [08/05/2025-11:42:50] [TRT] [I] ----------------------------------------------------------------
# [08/05/2025-11:42:50] [TRT] [I] Input filename:   /workspace/tao-experiments/unet/resnet18/weights/resnet18.onnx
# [08/05/2025-11:42:50] [TRT] [I] ONNX IR version:  0.0.6
# [08/05/2025-11:42:50] [TRT] [I] Opset version:    11
# [08/05/2025-11:42:50] [TRT] [I] Producer name:    tf2onnx
# [08/05/2025-11:42:50] [TRT] [I] Producer version: 1.9.2
# [08/05/2025-11:42:50] [TRT] [I] Domain:
# [08/05/2025-11:42:50] [TRT] [I] Model version:    0
# [08/05/2025-11:42:50] [TRT] [I] Doc string:
# [08/05/2025-11:42:50] [TRT] [I] ----------------------------------------------------------------
# [08/05/2025-11:42:50] [TRT] [W] Tensor DataType is determined at build time for tensors not marked as input or output.
# 2025-08-05 11:42:50,829 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 97: Network Description
# 2025-08-05 11:42:50,829 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 99: Input 'input_1:0' with shape (-1, 3, 512, 512) and dtype DataType.FLOAT
# 2025-08-05 11:42:50,829 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 101: Output 'argmax_1' with shape (-1, 512, 512, 1) and dtype DataType.INT32
# 2025-08-05 11:42:50,829 [TAO Toolkit] [INFO] nvidia_tao_deploy.cv.unet.engine_builder 104: dynamic batch size handling
# 2025-08-05 11:42:50,829 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 150: TensorRT engine build configurations:
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 163:
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 179:   BuilderFlag.TF32
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 195:
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 197:   Note: max representabile value is 2,147,483,648 bytes or 2GB.
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 199:   MemoryPoolType.WORKSPACE = 2147483648 bytes
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 201:   MemoryPoolType.DLA_MANAGED_SRAM = 0 bytes
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 203:   MemoryPoolType.DLA_LOCAL_DRAM = 1073741824 bytes
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 205:   MemoryPoolType.DLA_GLOBAL_DRAM = 536870912 bytes
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 207:
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 209:   PreviewFeature.FASTER_DYNAMIC_SHAPES_0805
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 211:   PreviewFeature.DISABLE_EXTERNAL_TACTIC_SOURCES_FOR_CORE_0805
# 2025-08-05 11:42:50,830 [TAO Toolkit] [INFO] nvidia_tao_deploy.engine.builder 215:   Tactic Sources = 31
# [08/05/2025-11:42:50] [TRT] [I] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [08/05/2025-11:42:51] [TRT] [I] Graph optimization time: 0.529756 seconds.
# [08/05/2025-11:42:51] [TRT] [I] BuilderFlag::kTF32 is set but hardware does not support TF32. Disabling TF32.
# [08/05/2025-11:42:51] [TRT] [I] Local timing cache in use. Profiling results in this builder pass will not be stored.
# [08/05/2025-11:43:43] [TRT] [I] Detected 1 inputs and 1 output network tensors.
# [08/05/2025-11:43:44] [TRT] [I] Total Host Persistent Memory: 121568
# [08/05/2025-11:43:44] [TRT] [I] Total Device Persistent Memory: 2226176
# [08/05/2025-11:43:44] [TRT] [I] Total Scratch Memory: 67108864
# [08/05/2025-11:43:44] [TRT] [I] [MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 25 MiB, GPU 1674 MiB
# [08/05/2025-11:43:44] [TRT] [I] [BlockAssignment] Started assigning block shifts. This will take 50 steps to complete.
# [08/05/2025-11:43:44] [TRT] [I] [BlockAssignment] Algorithm ShiftNTopDown took 0.847767ms to assign 7 blocks to 50 nodes requiring 1300234240 bytes.
# [08/05/2025-11:43:44] [TRT] [I] Total Activation Memory: 1300234240
# [08/05/2025-11:43:44] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in building engine: CPU +0, GPU +94, now: CPU 0, GPU 94 (MiB)
# Export finished successfully.
# 2025-08-05 11:43:44,788 [TAO Toolkit] [INFO] root 167: Gen_trt_engine finished successfully.
# [2025-08-05 11:43:45,129 - TAO Toolkit - nvidia_tao_deploy.cv.common.entrypoint.entrypoint_proto - INFO] Sending telemetry data.
# [2025-08-05 11:43:45,129 - TAO Toolkit - root - INFO] ================> Start Reporting Telemetry <================
# [2025-08-05 11:43:45,129 - TAO Toolkit - root - INFO] Sending {'version': '5.5.0', 'action': 'gen_trt_engine', 'network': 'unet', 'gpu': ['Tesla-T4'], 'success': True, 'time_lapsed': 61.1061429977417} to https://api.tao.ngc.nvidia.com.
# [2025-08-05 11:44:05,151 - TAO Toolkit - nvidia_tao_deploy.cv.common.entrypoint.entrypoint_proto - WARNING] Telemetry data couldn't be sent, but the command ran successfully.
# [2025-08-05 11:44:05,151 - TAO Toolkit - nvidia_tao_deploy.cv.common.entrypoint.entrypoint_proto - WARNING] [Error]: HTTPSConnectionPool(host='api.tao.ngc.nvidia.com', port=443): Max retries exceeded with url: /api/v1/metrics (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f357eaf6a40>: Failed to resolve 'api.tao.ngc.nvidia.com' ([Errno -3] Temporary failure in name resolution)"))
# [2025-08-05 11:44:05,151 - TAO Toolkit - nvidia_tao_deploy.cv.common.entrypoint.entrypoint_proto - INFO] Execution status: PASS
# 2025-08-05 11:44:05,373 [TAO Toolkit] [INFO] nvidia_tao_cli.components.docker_handler.docker_handler 363: Stopping container.

# %% [markdown]
# Note from the logs that the input layer is `input_1:0` and the output layer is `argmax_1`.

# %% [markdown]
# **Well Done!** Let's move to the [next notebook](./03_model_deployment_for_inference.ipynb).
